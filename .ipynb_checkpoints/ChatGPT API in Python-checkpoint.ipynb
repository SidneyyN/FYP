# %%
# !pip install -q openai --user
# Out:
# WARNING: Ignoring invalid distribution ~ip (C:\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Python312\Lib\site-packages)
#   WARNING: The script distro.exe is installed in 'C:\Users\Sidney\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script openai.exe is installed in 'C:\Users\Sidney\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
openai.api_key = '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'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 openai.api_key = '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'
#
# NameError: name 'openai' is not defined
