# %% [markdown]
# # Linear Regression for Experiments with Same Agents

# %% [markdown]
# We run linear regression on equation 9 of the paper Price stability and volatility in markets with positive and negative expectations feedback: An experimental investigation to get their beta values for comparison.

# %%
pip install openpyxl
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting et-xmlfile (from openpyxl)
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~ip (c:\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (c:\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (c:\Python312\Lib\site-packages)

# %%
pip install statsmodels
# Out:
# Collecting statsmodels
#   Downloading statsmodels-0.14.4-cp312-cp312-win_amd64.whl.metadata (9.5 kB)
# Requirement already satisfied: numpy<3,>=1.22.3 in c:\python312\lib\site-packages (from statsmodels) (2.1.2)
# Collecting scipy!=1.9.2,>=1.8 (from statsmodels)
#   Downloading scipy-1.15.1-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in c:\users\sidney\appdata\roaming\python\python312\site-packages (from statsmodels) (2.2.3)
# Collecting patsy>=0.5.6 (from statsmodels)
#   Downloading patsy-1.0.1-py2.py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: packaging>=21.3 in c:\python312\lib\site-packages (from statsmodels) (24.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\python312\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sidney\appdata\roaming\python\python312\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sidney\appdata\roaming\python\python312\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.16.0)
# Downloading statsmodels-0.14.4-cp312-cp312-win_amd64.whl (9.8 MB)
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    ---------------------- ----------------- 5.5/9.8 MB 25.8 MB/s eta 0:00:01
#    ---------------------------------------- 9.8/9.8 MB 29.2 MB/s eta 0:00:00
# Downloading patsy-1.0.1-py2.py3-none-any.whl (232 kB)
# Downloading scipy-1.15.1-cp312-cp312-win_amd64.whl (43.6 MB)
#    ---------------------------------------- 0.0/43.6 MB ? eta -:--:--
#    ------ --------------------------------- 7.3/43.6 MB 34.9 MB/s eta 0:00:02
#    ------------- -------------------------- 14.7/43.6 MB 35.5 MB/s eta 0:00:01
#    -------------------- ------------------- 22.3/43.6 MB 36.2 MB/s eta 0:00:01
#    -------------------------- ------------- 29.4/43.6 MB 35.8 MB/s eta 0:00:01
#    --------------------------------- ------ 36.4/43.6 MB 35.6 MB/s eta 0:00:01
#    ---------------------------------------  43.3/43.6 MB 35.3 MB/s eta 0:00:01
#    ---------------------------------------- 43.6/43.6 MB 34.3 MB/s eta 0:00:00
# Installing collected packages: scipy, patsy, statsmodels
# Successfully installed patsy-1.0.1 scipy-1.15.1 statsmodels-0.14.4
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~ip (c:\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (c:\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (c:\Python312\Lib\site-packages)

# %%
import pandas as pd
import statsmodels.api as sm

# %% [markdown]
# ## Basic Positive

# %%
# Step 1: Load the Excel file
# Replace 'your_file.xlsx' with the actual filename of your Excel file
file_path = '..\Linear Regression\Basic Positive.xlsx'  # Update this with your file path
data = pd.read_excel(file_path)
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\L'
# <>:3: SyntaxWarning: invalid escape sequence '\L'
# C:\Users\Sidney\AppData\Local\Temp\ipykernel_35620\356425686.py:3: SyntaxWarning: invalid escape sequence '\L'
#   file_path = '..\Linear Regression\Basic Positive.xlsx'  # Update this with your file path

# %%
# Step 2: Aggregate data by time step to calculate mean predicted and actual prices
aggregated_data = data.groupby('time_step').agg({
    'predicted_price': 'mean',      # Mean predicted price
    'actual_price': 'mean'    # Mean actual price
}).reset_index()

# %%
# Step 3: Create lagged variables
aggregated_data['p_t-1'] = aggregated_data['actual_price'].shift(1)
aggregated_data['p_t-2'] = aggregated_data['actual_price'].shift(2)
aggregated_data['p_e,h,t-1'] = aggregated_data['predicted_price'].shift(1)

# %%
# Step 4: Calculate price difference
aggregated_data['price_diff'] = aggregated_data['p_t-1'] - aggregated_data['p_t-2']

# %%
# Step 5: Drop rows with missing values due to lagging
aggregated_data = aggregated_data.dropna()

# %%
# Step 6: Prepare regression variables
X = aggregated_data[['p_t-1', 'p_e,h,t-1', 'price_diff']]  # Independent variables
X['constant'] = 60  # Add the constant term (60)
y = aggregated_data['predicted_price']  # Dependent variable (mean predicted price)
# Out:
# C:\Users\Sidney\AppData\Local\Temp\ipykernel_35620\689754166.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['constant'] = 60  # Add the constant term (60)

# %%
# Step 7: Add intercept for regression
X = sm.add_constant(X)

# %%
# Just to make sur that all columns in X are numeric 
X = X.apply(pd.to_numeric, errors='coerce')

# Ensure y is numeric as well
y = pd.to_numeric(y, errors='coerce')

# %%
# Step 8: Run the regression
model = sm.OLS(y, X).fit()

# %%
# Step 9: Output the regression results
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        predicted_price   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 6.095e+04
# Date:                Mon, 20 Jan 2025   Prob (F-statistic):           1.31e-79
# Time:                        14:26:32   Log-Likelihood:                 54.365
# No. Observations:                  48   AIC:                            -100.7
# Df Residuals:                      44   BIC:                            -93.24
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# p_t-1          0.1479      0.150      0.985      0.330      -0.155       0.450
# p_e,h,t-1      0.8473      0.144      5.882      0.000       0.557       1.138
# price_diff     0.9421      0.035     27.051      0.000       0.872       1.012
# constant       0.0057      0.007      0.837      0.407      -0.008       0.019
# ==============================================================================
# Omnibus:                        0.956   Durbin-Watson:                   2.192
# Prob(Omnibus):                  0.620   Jarque-Bera (JB):                0.735
# Skew:                           0.300   Prob(JB):                        0.693
# Kurtosis:                       2.914   Cond. No.                     1.92e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.92e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ## Basic Negative

# %%
# Step 1: Load the Excel file
# Replace 'your_file.xlsx' with the actual filename of your Excel file
file_path = '..\Linear Regression\Basic Negative.xlsx'  # Update this with your file path
data = pd.read_excel(file_path)
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\L'
# <>:3: SyntaxWarning: invalid escape sequence '\L'
# C:\Users\Sidney\AppData\Local\Temp\ipykernel_35620\4204849043.py:3: SyntaxWarning: invalid escape sequence '\L'
#   file_path = '..\Linear Regression\Basic Negative.xlsx'  # Update this with your file path

# %%
# Step 2: Aggregate data by time step to calculate mean predicted and actual prices
aggregated_data = data.groupby('time_step').agg({
    'predicted_price': 'mean',      # Mean predicted price
    'actual_price': 'mean'    # Mean actual price
}).reset_index()

# Step 3: Create lagged variables
aggregated_data['p_t-1'] = aggregated_data['actual_price'].shift(1)
aggregated_data['p_t-2'] = aggregated_data['actual_price'].shift(2)
aggregated_data['p_e,h,t-1'] = aggregated_data['predicted_price'].shift(1)

# Step 4: Calculate price difference
aggregated_data['price_diff'] = aggregated_data['p_t-1'] - aggregated_data['p_t-2']

# Step 5: Drop rows with missing values due to lagging
aggregated_data = aggregated_data.dropna()

# Step 6: Prepare regression variables
X = aggregated_data[['p_t-1', 'p_e,h,t-1', 'price_diff']]  # Independent variables
X['constant'] = 60  # Add the constant term (60)
y = aggregated_data['predicted_price']  # Dependent variable (mean predicted price)

# Step 7: Add intercept for regression
X = sm.add_constant(X)

# Just to make sur that all columns in X are numeric 
X = X.apply(pd.to_numeric, errors='coerce')

# Ensure y is numeric as well
y = pd.to_numeric(y, errors='coerce')

# Step 8: Run the regression
model = sm.OLS(y, X).fit()
# Out:
# C:\Users\Sidney\AppData\Local\Temp\ipykernel_35620\81247018.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['constant'] = 60  # Add the constant term (60)

# %%
# Step 9: Output the regression results
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        predicted_price   R-squared:                       0.977
# Model:                            OLS   Adj. R-squared:                  0.975
# Method:                 Least Squares   F-statistic:                     609.7
# Date:                Mon, 20 Jan 2025   Prob (F-statistic):           7.69e-36
# Time:                        14:41:46   Log-Likelihood:                -55.367
# No. Observations:                  48   AIC:                             118.7
# Df Residuals:                      44   BIC:                             126.2
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# p_t-1          0.1581      1.676      0.094      0.925      -3.220       3.536
# p_e,h,t-1     -1.4131      1.555     -0.909      0.368      -4.547       1.721
# price_diff    -0.3226      0.142     -2.274      0.028      -0.609      -0.037
# constant       2.2584      3.219      0.702      0.487      -4.229       8.746
# ==============================================================================
# Omnibus:                       15.468   Durbin-Watson:                   1.947
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               38.667
# Skew:                          -0.690   Prob(JB):                     4.01e-09
# Kurtosis:                       7.175   Cond. No.                     3.55e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.55e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ## Risk-Adverse Positive

# %%
# Step 1: Load the Excel file
# Replace 'your_file.xlsx' with the actual filename of your Excel file
file_path = '..\Linear Regression\Risk-Adverse Positive.xlsx'  # Update this with your file path
data = pd.read_excel(file_path)
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\L'
# <>:3: SyntaxWarning: invalid escape sequence '\L'
# C:\Users\Sidney\AppData\Local\Temp\ipykernel_35620\3639837812.py:3: SyntaxWarning: invalid escape sequence '\L'
#   file_path = '..\Linear Regression\Risk-Adverse Positive.xlsx'  # Update this with your file path

# %%
# Step 2: Aggregate data by time step to calculate mean predicted and actual prices
aggregated_data = data.groupby('time_step').agg({
    'predicted_price': 'mean',      # Mean predicted price
    'actual_price': 'mean'    # Mean actual price
}).reset_index()

# Step 3: Create lagged variables
aggregated_data['p_t-1'] = aggregated_data['actual_price'].shift(1)
aggregated_data['p_t-2'] = aggregated_data['actual_price'].shift(2)
aggregated_data['p_e,h,t-1'] = aggregated_data['predicted_price'].shift(1)

# Step 4: Calculate price difference
aggregated_data['price_diff'] = aggregated_data['p_t-1'] - aggregated_data['p_t-2']

# Step 5: Drop rows with missing values due to lagging
aggregated_data = aggregated_data.dropna()

# Step 6: Prepare regression variables
X = aggregated_data[['p_t-1', 'p_e,h,t-1', 'price_diff']]  # Independent variables
X['constant'] = 60  # Add the constant term (60)
y = aggregated_data['predicted_price']  # Dependent variable (mean predicted price)

# Step 7: Add intercept for regression
X = sm.add_constant(X)

# Just to make sur that all columns in X are numeric 
X = X.apply(pd.to_numeric, errors='coerce')

# Ensure y is numeric as well
y = pd.to_numeric(y, errors='coerce')

# Step 8: Run the regression
model = sm.OLS(y, X).fit()
# Out:
# C:\Users\Sidney\AppData\Local\Temp\ipykernel_35620\81247018.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['constant'] = 60  # Add the constant term (60)

# %%
# Step 9: Output the regression results
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        predicted_price   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 8.139e+04
# Date:                Mon, 20 Jan 2025   Prob (F-statistic):           2.27e-82
# Time:                        17:42:23   Log-Likelihood:                 60.406
# No. Observations:                  48   AIC:                            -112.8
# Df Residuals:                      44   BIC:                            -105.3
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# p_t-1         -0.3434      0.127     -2.703      0.010      -0.599      -0.087
# p_e,h,t-1      1.3191      0.122     10.842      0.000       1.074       1.564
# price_diff     0.9217      0.044     21.077      0.000       0.834       1.010
# constant       0.0250      0.006      4.128      0.000       0.013       0.037
# ==============================================================================
# Omnibus:                        5.482   Durbin-Watson:                   2.666
# Prob(Omnibus):                  0.064   Jarque-Bera (JB):                4.959
# Skew:                           0.454   Prob(JB):                       0.0838
# Kurtosis:                       4.286   Cond. No.                     1.81e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.81e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ## Risk-Adverse Negative

# %%
# Step 1: Load the Excel file
# Replace 'your_file.xlsx' with the actual filename of your Excel file
file_path = '..\Linear Regression\Risk-Adverse Negative.xlsx'  # Update this with your file path
data = pd.read_excel(file_path)
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\L'
# <>:3: SyntaxWarning: invalid escape sequence '\L'
# C:\Users\Sidney\AppData\Local\Temp\ipykernel_35620\360418011.py:3: SyntaxWarning: invalid escape sequence '\L'
#   file_path = '..\Linear Regression\Risk-Adverse Negative.xlsx'  # Update this with your file path

# %%
# Step 2: Aggregate data by time step to calculate mean predicted and actual prices
aggregated_data = data.groupby('time_step').agg({
    'predicted_price': 'mean',      # Mean predicted price
    'actual_price': 'mean'    # Mean actual price
}).reset_index()

# Step 3: Create lagged variables
aggregated_data['p_t-1'] = aggregated_data['actual_price'].shift(1)
aggregated_data['p_t-2'] = aggregated_data['actual_price'].shift(2)
aggregated_data['p_e,h,t-1'] = aggregated_data['predicted_price'].shift(1)

# Step 4: Calculate price difference
aggregated_data['price_diff'] = aggregated_data['p_t-1'] - aggregated_data['p_t-2']

# Step 5: Drop rows with missing values due to lagging
aggregated_data = aggregated_data.dropna()

# Step 6: Prepare regression variables
X = aggregated_data[['p_t-1', 'p_e,h,t-1', 'price_diff']]  # Independent variables
X['constant'] = 60  # Add the constant term (60)
y = aggregated_data['predicted_price']  # Dependent variable (mean predicted price)

# Step 7: Add intercept for regression
X = sm.add_constant(X)

# Just to make sur that all columns in X are numeric 
X = X.apply(pd.to_numeric, errors='coerce')

# Ensure y is numeric as well
y = pd.to_numeric(y, errors='coerce')

# Step 8: Run the regression
model = sm.OLS(y, X).fit()
# Out:
# C:\Users\Sidney\AppData\Local\Temp\ipykernel_35620\81247018.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['constant'] = 60  # Add the constant term (60)

# %%
# Step 9: Output the regression results
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        predicted_price   R-squared:                       0.953
# Model:                            OLS   Adj. R-squared:                  0.950
# Method:                 Least Squares   F-statistic:                     299.5
# Date:                Mon, 20 Jan 2025   Prob (F-statistic):           2.78e-29
# Time:                        17:46:02   Log-Likelihood:                -25.127
# No. Observations:                  48   AIC:                             58.25
# Df Residuals:                      44   BIC:                             65.74
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# p_t-1          0.2300      0.727      0.316      0.753      -1.236       1.696
# p_e,h,t-1      0.5947      0.716      0.831      0.410      -0.847       2.037
# price_diff     0.5837      0.100      5.860      0.000       0.383       0.784
# constant       0.1701      1.427      0.119      0.906      -2.707       3.047
# ==============================================================================
# Omnibus:                       46.596   Durbin-Watson:                   2.349
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              206.574
# Skew:                          -2.479   Prob(JB):                     1.39e-45
# Kurtosis:                      11.871   Cond. No.                     2.95e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.95e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ## Risk-Neutral Positive

# %%
# Step 1: Load the Excel file
# Replace 'your_file.xlsx' with the actual filename of your Excel file
file_path = '..\Linear Regression\Risk-Neutral Positive.xlsx'  # Update this with your file path
data = pd.read_excel(file_path)
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\L'
# <>:3: SyntaxWarning: invalid escape sequence '\L'
# C:\Users\Sidney\AppData\Local\Temp\ipykernel_35620\1634972204.py:3: SyntaxWarning: invalid escape sequence '\L'
#   file_path = '..\Linear Regression\Risk-Neutral Positive.xlsx'  # Update this with your file path

# %%
# Step 2: Aggregate data by time step to calculate mean predicted and actual prices
aggregated_data = data.groupby('time_step').agg({
    'predicted_price': 'mean',      # Mean predicted price
    'actual_price': 'mean'    # Mean actual price
}).reset_index()

# Step 3: Create lagged variables
aggregated_data['p_t-1'] = aggregated_data['actual_price'].shift(1)
aggregated_data['p_t-2'] = aggregated_data['actual_price'].shift(2)
aggregated_data['p_e,h,t-1'] = aggregated_data['predicted_price'].shift(1)

# Step 4: Calculate price difference
aggregated_data['price_diff'] = aggregated_data['p_t-1'] - aggregated_data['p_t-2']

# Step 5: Drop rows with missing values due to lagging
aggregated_data = aggregated_data.dropna()

# Step 6: Prepare regression variables
X = aggregated_data[['p_t-1', 'p_e,h,t-1', 'price_diff']]  # Independent variables
X['constant'] = 60  # Add the constant term (60)
y = aggregated_data['predicted_price']  # Dependent variable (mean predicted price)

# Step 7: Add intercept for regression
X = sm.add_constant(X)

# Just to make sur that all columns in X are numeric 
X = X.apply(pd.to_numeric, errors='coerce')

# Ensure y is numeric as well
y = pd.to_numeric(y, errors='coerce')

# Step 8: Run the regression
model = sm.OLS(y, X).fit()
# Out:
# C:\Users\Sidney\AppData\Local\Temp\ipykernel_35620\81247018.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['constant'] = 60  # Add the constant term (60)

# %%
# Step 9: Output the regression results
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        predicted_price   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 7.427e+04
# Date:                Mon, 20 Jan 2025   Prob (F-statistic):           1.70e-81
# Time:                        17:48:14   Log-Likelihood:                 62.716
# No. Observations:                  48   AIC:                            -117.4
# Df Residuals:                      44   BIC:                            -109.9
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# p_t-1         -0.3144      0.121     -2.606      0.012      -0.558      -0.071
# p_e,h,t-1      1.2859      0.115     11.149      0.000       1.053       1.518
# price_diff     0.8942      0.036     24.819      0.000       0.822       0.967
# constant       0.0295      0.006      4.823      0.000       0.017       0.042
# ==============================================================================
# Omnibus:                        0.247   Durbin-Watson:                   2.323
# Prob(Omnibus):                  0.884   Jarque-Bera (JB):                0.264
# Skew:                          -0.155   Prob(JB):                        0.876
# Kurtosis:                       2.810   Cond. No.                     1.80e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.8e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ## Risk-Neutral Negative

# %%
# Step 1: Load the Excel file
# Replace 'your_file.xlsx' with the actual filename of your Excel file
file_path = '..\Linear Regression\Risk-Neutral Negative.xlsx'  # Update this with your file path
data = pd.read_excel(file_path)
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\L'
# <>:3: SyntaxWarning: invalid escape sequence '\L'
# C:\Users\Sidney\AppData\Local\Temp\ipykernel_35620\2932675767.py:3: SyntaxWarning: invalid escape sequence '\L'
#   file_path = '..\Linear Regression\Risk-Neutral Negative.xlsx'  # Update this with your file path

# %%
# Step 2: Aggregate data by time step to calculate mean predicted and actual prices
aggregated_data = data.groupby('time_step').agg({
    'predicted_price': 'mean',      # Mean predicted price
    'actual_price': 'mean'    # Mean actual price
}).reset_index()

# Step 3: Create lagged variables
aggregated_data['p_t-1'] = aggregated_data['actual_price'].shift(1)
aggregated_data['p_t-2'] = aggregated_data['actual_price'].shift(2)
aggregated_data['p_e,h,t-1'] = aggregated_data['predicted_price'].shift(1)

# Step 4: Calculate price difference
aggregated_data['price_diff'] = aggregated_data['p_t-1'] - aggregated_data['p_t-2']

# Step 5: Drop rows with missing values due to lagging
aggregated_data = aggregated_data.dropna()

# Step 6: Prepare regression variables
X = aggregated_data[['p_t-1', 'p_e,h,t-1', 'price_diff']]  # Independent variables
X['constant'] = 60  # Add the constant term (60)
y = aggregated_data['predicted_price']  # Dependent variable (mean predicted price)

# Step 7: Add intercept for regression
X = sm.add_constant(X)

# Just to make sur that all columns in X are numeric 
X = X.apply(pd.to_numeric, errors='coerce')

# Ensure y is numeric as well
y = pd.to_numeric(y, errors='coerce')

# Step 8: Run the regression
model = sm.OLS(y, X).fit()
# Out:
# C:\Users\Sidney\AppData\Local\Temp\ipykernel_35620\81247018.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['constant'] = 60  # Add the constant term (60)

# %%
# Step 9: Output the regression results
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        predicted_price   R-squared:                       0.982
# Model:                            OLS   Adj. R-squared:                  0.981
# Method:                 Least Squares   F-statistic:                     792.6
# Date:                Mon, 20 Jan 2025   Prob (F-statistic):           2.71e-38
# Time:                        17:51:44   Log-Likelihood:                -22.610
# No. Observations:                  48   AIC:                             53.22
# Df Residuals:                      44   BIC:                             60.71
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# p_t-1          0.7848      0.738      1.064      0.293      -0.702       2.272
# p_e,h,t-1      0.4867      0.690      0.705      0.484      -0.904       1.877
# price_diff     0.3204      0.134      2.396      0.021       0.051       0.590
# constant      -0.2697      1.401     -0.192      0.848      -3.094       2.554
# ==============================================================================
# Omnibus:                        8.544   Durbin-Watson:                   2.034
# Prob(Omnibus):                  0.014   Jarque-Bera (JB):               14.871
# Skew:                           0.329   Prob(JB):                     0.000590
# Kurtosis:                       5.646   Cond. No.                     3.05e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.05e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ## Risk-Seeking Positive

# %%
# Step 1: Load the Excel file
# Replace 'your_file.xlsx' with the actual filename of your Excel file
file_path = '..\Linear Regression\Risk-Seeking Positive.xlsx'  # Update this with your file path
data = pd.read_excel(file_path)
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\L'
# <>:3: SyntaxWarning: invalid escape sequence '\L'
# C:\Users\Sidney\AppData\Local\Temp\ipykernel_35620\2748762268.py:3: SyntaxWarning: invalid escape sequence '\L'
#   file_path = '..\Linear Regression\Risk-Seeking Positive.xlsx'  # Update this with your file path

# %%
# Step 2: Aggregate data by time step to calculate mean predicted and actual prices
aggregated_data = data.groupby('time_step').agg({
    'predicted_price': 'mean',      # Mean predicted price
    'actual_price': 'mean'    # Mean actual price
}).reset_index()

# Step 3: Create lagged variables
aggregated_data['p_t-1'] = aggregated_data['actual_price'].shift(1)
aggregated_data['p_t-2'] = aggregated_data['actual_price'].shift(2)
aggregated_data['p_e,h,t-1'] = aggregated_data['predicted_price'].shift(1)

# Step 4: Calculate price difference
aggregated_data['price_diff'] = aggregated_data['p_t-1'] - aggregated_data['p_t-2']

# Step 5: Drop rows with missing values due to lagging
aggregated_data = aggregated_data.dropna()

# Step 6: Prepare regression variables
X = aggregated_data[['p_t-1', 'p_e,h,t-1', 'price_diff']]  # Independent variables
X['constant'] = 60  # Add the constant term (60)
y = aggregated_data['predicted_price']  # Dependent variable (mean predicted price)

# Step 7: Add intercept for regression
X = sm.add_constant(X)

# Just to make sur that all columns in X are numeric 
X = X.apply(pd.to_numeric, errors='coerce')

# Ensure y is numeric as well
y = pd.to_numeric(y, errors='coerce')

# Step 8: Run the regression
model = sm.OLS(y, X).fit()
# Out:
# C:\Users\Sidney\AppData\Local\Temp\ipykernel_35620\81247018.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['constant'] = 60  # Add the constant term (60)

# %%
# Step 9: Output the regression results
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        predicted_price   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 3.245e+04
# Date:                Mon, 20 Jan 2025   Prob (F-statistic):           1.38e-73
# Time:                        17:53:03   Log-Likelihood:                 17.148
# No. Observations:                  48   AIC:                            -26.30
# Df Residuals:                      44   BIC:                            -18.81
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# p_t-1          0.1866      0.306      0.610      0.545      -0.430       0.803
# p_e,h,t-1      0.8173      0.291      2.806      0.007       0.230       1.404
# price_diff     0.9596      0.028     34.063      0.000       0.903       1.016
# constant      -0.0033      0.015     -0.214      0.832      -0.034       0.028
# ==============================================================================
# Omnibus:                        7.436   Durbin-Watson:                   2.145
# Prob(Omnibus):                  0.024   Jarque-Bera (JB):                6.682
# Skew:                           0.688   Prob(JB):                       0.0354
# Kurtosis:                       4.202   Cond. No.                     2.02e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.02e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ## Risk-Seeking Negative

# %%
# Step 1: Load the Excel file
# Replace 'your_file.xlsx' with the actual filename of your Excel file
file_path = '..\Linear Regression\Risk-Seeking Negative.xlsx'  # Update this with your file path
data = pd.read_excel(file_path)
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\L'
# <>:3: SyntaxWarning: invalid escape sequence '\L'
# C:\Users\Sidney\AppData\Local\Temp\ipykernel_35620\1733036204.py:3: SyntaxWarning: invalid escape sequence '\L'
#   file_path = '..\Linear Regression\Risk-Seeking Negative.xlsx'  # Update this with your file path

# %%
# Step 2: Aggregate data by time step to calculate mean predicted and actual prices
aggregated_data = data.groupby('time_step').agg({
    'predicted_price': 'mean',      # Mean predicted price
    'actual_price': 'mean'    # Mean actual price
}).reset_index()

# Step 3: Create lagged variables
aggregated_data['p_t-1'] = aggregated_data['actual_price'].shift(1)
aggregated_data['p_t-2'] = aggregated_data['actual_price'].shift(2)
aggregated_data['p_e,h,t-1'] = aggregated_data['predicted_price'].shift(1)

# Step 4: Calculate price difference
aggregated_data['price_diff'] = aggregated_data['p_t-1'] - aggregated_data['p_t-2']

# Step 5: Drop rows with missing values due to lagging
aggregated_data = aggregated_data.dropna()

# Step 6: Prepare regression variables
X = aggregated_data[['p_t-1', 'p_e,h,t-1', 'price_diff']]  # Independent variables
X['constant'] = 60  # Add the constant term (60)
y = aggregated_data['predicted_price']  # Dependent variable (mean predicted price)

# Step 7: Add intercept for regression
X = sm.add_constant(X)

# Just to make sur that all columns in X are numeric 
X = X.apply(pd.to_numeric, errors='coerce')

# Ensure y is numeric as well
y = pd.to_numeric(y, errors='coerce')

# Step 8: Run the regression
model = sm.OLS(y, X).fit()
# Out:
# C:\Users\Sidney\AppData\Local\Temp\ipykernel_35620\81247018.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['constant'] = 60  # Add the constant term (60)

# %%
# Step 9: Output the regression results
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        predicted_price   R-squared:                       0.950
# Model:                            OLS   Adj. R-squared:                  0.946
# Method:                 Least Squares   F-statistic:                     277.1
# Date:                Mon, 20 Jan 2025   Prob (F-statistic):           1.41e-28
# Time:                        17:54:18   Log-Likelihood:                -67.049
# No. Observations:                  48   AIC:                             142.1
# Df Residuals:                      44   BIC:                             149.6
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# p_t-1         -0.5519      2.043     -0.270      0.788      -4.669       3.566
# p_e,h,t-1     -1.3199      1.956     -0.675      0.503      -5.262       2.623
# price_diff     0.0066      0.117      0.056      0.956      -0.230       0.243
# constant       2.8832      3.991      0.722      0.474      -5.161      10.927
# ==============================================================================
# Omnibus:                       53.350   Durbin-Watson:                   2.106
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              294.306
# Skew:                           2.843   Prob(JB):                     1.24e-64
# Kurtosis:                      13.715   Cond. No.                     3.45e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.45e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ## Aggressive Speculator Positive (NO CONSTRAINTS)

# %%
# Step 1: Load the Excel file
# Replace 'your_file.xlsx' with the actual filename of your Excel file
file_path = '..\Linear Regression\Aggressive Speculator Positive.xlsx'  # Update this with your file path
data = pd.read_excel(file_path)
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\L'
# <>:3: SyntaxWarning: invalid escape sequence '\L'
# C:\Users\Sidney\AppData\Local\Temp\ipykernel_57280\567272936.py:3: SyntaxWarning: invalid escape sequence '\L'
#   file_path = '..\Linear Regression\Aggressive Speculator Positive.xlsx'  # Update this with your file path

# %%
# Step 2: Aggregate data by time step to calculate mean predicted and actual prices
aggregated_data = data.groupby('time_step').agg({
    'predicted_price': 'mean',      # Mean predicted price
    'actual_price': 'mean'    # Mean actual price
}).reset_index()

# Step 3: Create lagged variables
aggregated_data['p_t-1'] = aggregated_data['actual_price'].shift(1)
aggregated_data['p_t-2'] = aggregated_data['actual_price'].shift(2)
aggregated_data['p_e,h,t-1'] = aggregated_data['predicted_price'].shift(1)

# Step 4: Calculate price difference
aggregated_data['price_diff'] = aggregated_data['p_t-1'] - aggregated_data['p_t-2']

# Step 5: Drop rows with missing values due to lagging
aggregated_data = aggregated_data.dropna()

# Step 6: Prepare regression variables
X = aggregated_data[['p_t-1', 'p_e,h,t-1', 'price_diff']]  # Independent variables
X['constant'] = 60  # Add the constant term (60)
y = aggregated_data['predicted_price']  # Dependent variable (mean predicted price)

# Step 7: Add intercept for regression
X = sm.add_constant(X)

# Just to make sur that all columns in X are numeric 
X = X.apply(pd.to_numeric, errors='coerce')

# Ensure y is numeric as well
y = pd.to_numeric(y, errors='coerce')

# Step 8: Run the regression
model = sm.OLS(y, X).fit()
# Out:
# C:\Users\Sidney\AppData\Local\Temp\ipykernel_57280\81247018.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['constant'] = 60  # Add the constant term (60)

# %%
# Step 9: Output the regression results
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        predicted_price   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 7.628e+04
# Date:                Wed, 05 Feb 2025   Prob (F-statistic):           9.45e-82
# Time:                        00:58:35   Log-Likelihood:                -31.779
# No. Observations:                  48   AIC:                             71.56
# Df Residuals:                      44   BIC:                             79.04
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# p_t-1         -1.5844      0.948     -1.671      0.102      -3.495       0.326
# p_e,h,t-1      2.5134      0.903      2.783      0.008       0.693       4.334
# price_diff     0.7956      0.042     19.057      0.000       0.711       0.880
# constant       0.0752      0.045      1.662      0.104      -0.016       0.166
# ==============================================================================
# Omnibus:                        3.349   Durbin-Watson:                   1.506
# Prob(Omnibus):                  0.187   Jarque-Bera (JB):                2.909
# Skew:                           0.098   Prob(JB):                        0.234
# Kurtosis:                       4.190   Cond. No.                     3.63e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.63e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ## Aggressive Speculator Positive (WITH CONSTRAINTS)

# %%
# Step 1: Load the Excel file
# Replace 'your_file.xlsx' with the actual filename of your Excel file
file_path = '../results/experiments/experiment_batch_20250316_175510_Pos_Aggr_Speculator_Constraint/consolidated_results.csv'  # Update this with your file path
data = pd.read_csv(file_path)

# Step 2: Aggregate data by time step to calculate mean predicted and actual prices
aggregated_data = data.groupby('time_step').agg({
    'mean_predicted_price': 'mean',      # Mean predicted price
    'mean_actual_price': 'mean'    # Mean actual price
}).reset_index()

# Step 3: Create lagged variables
aggregated_data['p_t-1'] = aggregated_data['mean_actual_price'].shift(1)
aggregated_data['p_t-2'] = aggregated_data['mean_actual_price'].shift(2)
aggregated_data['p_e,h,t-1'] = aggregated_data['mean_predicted_price'].shift(1)

# Step 4: Calculate price difference
aggregated_data['price_diff'] = aggregated_data['p_t-1'] - aggregated_data['p_t-2']

# Step 5: Drop rows with missing values due to lagging
aggregated_data = aggregated_data.dropna()

# Step 6: Prepare regression variables
X = aggregated_data[['p_t-1', 'p_e,h,t-1', 'price_diff']]  # Independent variables
X['constant'] = 60  # Add the constant term (60)
y = aggregated_data['mean_predicted_price']  # Dependent variable (mean predicted price)

# Step 7: Add intercept for regression
X = sm.add_constant(X)

# Just to make sur that all columns in X are numeric 
X = X.apply(pd.to_numeric, errors='coerce')

# Ensure y is numeric as well
y = pd.to_numeric(y, errors='coerce')

# Step 8: Run the regression
model = sm.OLS(y, X).fit()

# Step 9: Output the regression results
print(model.summary())
# Out:
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     mean_predicted_price   R-squared:                       0.983
# Model:                              OLS   Adj. R-squared:                  0.982
# Method:                   Least Squares   F-statistic:                     856.4
# Date:                  Sun, 16 Mar 2025   Prob (F-statistic):           5.07e-39
# Time:                          18:44:39   Log-Likelihood:                -28.473
# No. Observations:                    48   AIC:                             64.95
# Df Residuals:                        44   BIC:                             72.43
# Df Model:                             3
# Covariance Type:              nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# p_t-1         -0.5193      0.891     -0.583      0.563      -2.316       1.277
# p_e,h,t-1      1.4195      0.848      1.674      0.101      -0.289       3.128
# price_diff     0.6820      0.050     13.602      0.000       0.581       0.783
# constant       0.1423      0.058      2.458      0.018       0.026       0.259
# ==============================================================================
# Omnibus:                        2.089   Durbin-Watson:                   2.201
# Prob(Omnibus):                  0.352   Jarque-Bera (JB):                1.180
# Skew:                           0.268   Prob(JB):                        0.554
# Kurtosis:                       3.550   Cond. No.                     2.70e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.7e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# C:\Users\Sidney\AppData\Local\Temp\ipykernel_25764\346472831.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['constant'] = 60  # Add the constant term (60)

# %% [markdown]
# ## Momentum Trader Positive

# %%
# Step 1: Load the Excel file
# Replace 'your_file.xlsx' with the actual filename of your Excel file
file_path = '..\Linear Regression\Momentum Trader Positive.xlsx'  # Update this with your file path
data = pd.read_excel(file_path)
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\L'
# <>:3: SyntaxWarning: invalid escape sequence '\L'
# C:\Users\Sidney\AppData\Local\Temp\ipykernel_57280\415378883.py:3: SyntaxWarning: invalid escape sequence '\L'
#   file_path = '..\Linear Regression\Momentum Trader Positive.xlsx'  # Update this with your file path

# %%
# Step 2: Aggregate data by time step to calculate mean predicted and actual prices
aggregated_data = data.groupby('time_step').agg({
    'predicted_price': 'mean',      # Mean predicted price
    'actual_price': 'mean'    # Mean actual price
}).reset_index()

# Step 3: Create lagged variables
aggregated_data['p_t-1'] = aggregated_data['actual_price'].shift(1)
aggregated_data['p_t-2'] = aggregated_data['actual_price'].shift(2)
aggregated_data['p_e,h,t-1'] = aggregated_data['predicted_price'].shift(1)

# Step 4: Calculate price difference
aggregated_data['price_diff'] = aggregated_data['p_t-1'] - aggregated_data['p_t-2']

# Step 5: Drop rows with missing values due to lagging
aggregated_data = aggregated_data.dropna()

# Step 6: Prepare regression variables
X = aggregated_data[['p_t-1', 'p_e,h,t-1', 'price_diff']]  # Independent variables
X['constant'] = 60  # Add the constant term (60)
y = aggregated_data['predicted_price']  # Dependent variable (mean predicted price)

# Step 7: Add intercept for regression
X = sm.add_constant(X)

# Just to make sur that all columns in X are numeric 
X = X.apply(pd.to_numeric, errors='coerce')

# Ensure y is numeric as well
y = pd.to_numeric(y, errors='coerce')

# Step 8: Run the regression
model = sm.OLS(y, X).fit()
# Out:
# C:\Users\Sidney\AppData\Local\Temp\ipykernel_57280\81247018.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['constant'] = 60  # Add the constant term (60)

# %%
# Step 9: Output the regression results
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        predicted_price   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 8.935e+04
# Date:                Wed, 05 Feb 2025   Prob (F-statistic):           2.91e-83
# Time:                        01:07:35   Log-Likelihood:                 59.258
# No. Observations:                  48   AIC:                            -110.5
# Df Residuals:                      44   BIC:                            -103.0
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# p_t-1          0.0148      0.144      0.103      0.918      -0.275       0.304
# p_e,h,t-1      0.9771      0.137      7.110      0.000       0.700       1.254
# price_diff     0.9423      0.046     20.663      0.000       0.850       1.034
# constant       0.0090      0.007      1.278      0.208      -0.005       0.023
# ==============================================================================
# Omnibus:                        1.883   Durbin-Watson:                   2.530
# Prob(Omnibus):                  0.390   Jarque-Bera (JB):                1.802
# Skew:                          -0.440   Prob(JB):                        0.406
# Kurtosis:                       2.646   Cond. No.                     2.05e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.05e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ## Balanced Decision Maker Positive

# %%
# Step 1: Load the Excel file
# Replace 'your_file.xlsx' with the actual filename of your Excel file
file_path = '..\Linear Regression\Balanced Decision-Maker Positive.xlsx'  # Update this with your file path
data = pd.read_excel(file_path)
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\L'
# <>:3: SyntaxWarning: invalid escape sequence '\L'
# C:\Users\Sidney\AppData\Local\Temp\ipykernel_57280\1716012569.py:3: SyntaxWarning: invalid escape sequence '\L'
#   file_path = '..\Linear Regression\Balanced Decision-Maker Positive.xlsx'  # Update this with your file path

# %%
# Step 2: Aggregate data by time step to calculate mean predicted and actual prices
aggregated_data = data.groupby('time_step').agg({
    'predicted_price': 'mean',      # Mean predicted price
    'actual_price': 'mean'    # Mean actual price
}).reset_index()

# Step 3: Create lagged variables
aggregated_data['p_t-1'] = aggregated_data['actual_price'].shift(1)
aggregated_data['p_t-2'] = aggregated_data['actual_price'].shift(2)
aggregated_data['p_e,h,t-1'] = aggregated_data['predicted_price'].shift(1)

# Step 4: Calculate price difference
aggregated_data['price_diff'] = aggregated_data['p_t-1'] - aggregated_data['p_t-2']

# Step 5: Drop rows with missing values due to lagging
aggregated_data = aggregated_data.dropna()

# Step 6: Prepare regression variables
X = aggregated_data[['p_t-1', 'p_e,h,t-1', 'price_diff']]  # Independent variables
X['constant'] = 60  # Add the constant term (60)
y = aggregated_data['predicted_price']  # Dependent variable (mean predicted price)

# Step 7: Add intercept for regression
X = sm.add_constant(X)

# Just to make sur that all columns in X are numeric 
X = X.apply(pd.to_numeric, errors='coerce')

# Ensure y is numeric as well
y = pd.to_numeric(y, errors='coerce')

# Step 8: Run the regression
model = sm.OLS(y, X).fit()
# Out:
# C:\Users\Sidney\AppData\Local\Temp\ipykernel_57280\81247018.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['constant'] = 60  # Add the constant term (60)

# %%
# Step 9: Output the regression results
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        predicted_price   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 4.974e+04
# Date:                Wed, 05 Feb 2025   Prob (F-statistic):           1.15e-77
# Time:                        01:10:53   Log-Likelihood:                 52.652
# No. Observations:                  48   AIC:                            -97.30
# Df Residuals:                      44   BIC:                            -89.82
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# p_t-1          0.0291      0.165      0.177      0.860      -0.303       0.361
# p_e,h,t-1      0.9617      0.157      6.106      0.000       0.644       1.279
# price_diff     0.9108      0.051     17.793      0.000       0.808       1.014
# constant       0.0100      0.008      1.223      0.228      -0.006       0.027
# ==============================================================================
# Omnibus:                        4.304   Durbin-Watson:                   2.604
# Prob(Omnibus):                  0.116   Jarque-Bera (JB):                3.216
# Skew:                          -0.590   Prob(JB):                        0.200
# Kurtosis:                       3.464   Cond. No.                     2.00e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large,  2e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ## Market Analyst Positive

# %%
# Step 1: Load the Excel file
# Replace 'your_file.xlsx' with the actual filename of your Excel file
file_path = '..\Linear Regression\Market Analyst Positive.xlsx'  # Update this with your file path
data = pd.read_excel(file_path)
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\L'
# <>:3: SyntaxWarning: invalid escape sequence '\L'
# C:\Users\Sidney\AppData\Local\Temp\ipykernel_57280\3886042415.py:3: SyntaxWarning: invalid escape sequence '\L'
#   file_path = '..\Linear Regression\Market Analyst Positive.xlsx'  # Update this with your file path

# %%
# Step 2: Aggregate data by time step to calculate mean predicted and actual prices
aggregated_data = data.groupby('time_step').agg({
    'predicted_price': 'mean',      # Mean predicted price
    'actual_price': 'mean'    # Mean actual price
}).reset_index()

# Step 3: Create lagged variables
aggregated_data['p_t-1'] = aggregated_data['actual_price'].shift(1)
aggregated_data['p_t-2'] = aggregated_data['actual_price'].shift(2)
aggregated_data['p_e,h,t-1'] = aggregated_data['predicted_price'].shift(1)

# Step 4: Calculate price difference
aggregated_data['price_diff'] = aggregated_data['p_t-1'] - aggregated_data['p_t-2']

# Step 5: Drop rows with missing values due to lagging
aggregated_data = aggregated_data.dropna()

# Step 6: Prepare regression variables
X = aggregated_data[['p_t-1', 'p_e,h,t-1', 'price_diff']]  # Independent variables
X['constant'] = 60  # Add the constant term (60)
y = aggregated_data['predicted_price']  # Dependent variable (mean predicted price)

# Step 7: Add intercept for regression
X = sm.add_constant(X)

# Just to make sur that all columns in X are numeric 
X = X.apply(pd.to_numeric, errors='coerce')

# Ensure y is numeric as well
y = pd.to_numeric(y, errors='coerce')

# Step 8: Run the regression
model = sm.OLS(y, X).fit()
# Out:
# C:\Users\Sidney\AppData\Local\Temp\ipykernel_57280\81247018.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['constant'] = 60  # Add the constant term (60)

# %%
# Step 9: Output the regression results
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        predicted_price   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 5.168e+04
# Date:                Wed, 05 Feb 2025   Prob (F-statistic):           4.95e-78
# Time:                        01:14:02   Log-Likelihood:                 45.856
# No. Observations:                  48   AIC:                            -83.71
# Df Residuals:                      44   BIC:                            -76.23
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# p_t-1          0.0099      0.189      0.052      0.958      -0.371       0.391
# p_e,h,t-1      0.9791      0.181      5.421      0.000       0.615       1.343
# price_diff     0.9253      0.047     19.727      0.000       0.831       1.020
# constant       0.0123      0.009      1.322      0.193      -0.006       0.031
# ==============================================================================
# Omnibus:                        1.238   Durbin-Watson:                   2.361
# Prob(Omnibus):                  0.539   Jarque-Bera (JB):                0.976
# Skew:                          -0.019   Prob(JB):                        0.614
# Kurtosis:                       2.302   Cond. No.                     2.05e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.05e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ## Contrarian Investor Positive

# %%
# Step 1: Load the Excel file
# Replace 'your_file.xlsx' with the actual filename of your Excel file
file_path = '..\Linear Regression\Contrarian Investor Positive.xlsx'  # Update this with your file path
data = pd.read_excel(file_path)
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\L'
# <>:3: SyntaxWarning: invalid escape sequence '\L'
# C:\Users\Sidney\AppData\Local\Temp\ipykernel_57280\1292551272.py:3: SyntaxWarning: invalid escape sequence '\L'
#   file_path = '..\Linear Regression\Contrarian Investor Positive.xlsx'  # Update this with your file path

# %%
# Step 2: Aggregate data by time step to calculate mean predicted and actual prices
aggregated_data = data.groupby('time_step').agg({
    'predicted_price': 'mean',      # Mean predicted price
    'actual_price': 'mean'    # Mean actual price
}).reset_index()

# Step 3: Create lagged variables
aggregated_data['p_t-1'] = aggregated_data['actual_price'].shift(1)
aggregated_data['p_t-2'] = aggregated_data['actual_price'].shift(2)
aggregated_data['p_e,h,t-1'] = aggregated_data['predicted_price'].shift(1)

# Step 4: Calculate price difference
aggregated_data['price_diff'] = aggregated_data['p_t-1'] - aggregated_data['p_t-2']

# Step 5: Drop rows with missing values due to lagging
aggregated_data = aggregated_data.dropna()

# Step 6: Prepare regression variables
X = aggregated_data[['p_t-1', 'p_e,h,t-1', 'price_diff']]  # Independent variables
X['constant'] = 60  # Add the constant term (60)
y = aggregated_data['predicted_price']  # Dependent variable (mean predicted price)

# Step 7: Add intercept for regression
X = sm.add_constant(X)

# Just to make sur that all columns in X are numeric 
X = X.apply(pd.to_numeric, errors='coerce')

# Ensure y is numeric as well
y = pd.to_numeric(y, errors='coerce')

# Step 8: Run the regression
model = sm.OLS(y, X).fit()
# Out:
# C:\Users\Sidney\AppData\Local\Temp\ipykernel_57280\81247018.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['constant'] = 60  # Add the constant term (60)

# %%
# Step 9: Output the regression results
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        predicted_price   R-squared:                       0.998
# Model:                            OLS   Adj. R-squared:                  0.998
# Method:                 Least Squares   F-statistic:                     8015.
# Date:                Wed, 05 Feb 2025   Prob (F-statistic):           3.06e-60
# Time:                        01:15:51   Log-Likelihood:                 37.509
# No. Observations:                  48   AIC:                            -67.02
# Df Residuals:                      44   BIC:                            -59.53
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# p_t-1         -0.1117      0.237     -0.471      0.640      -0.590       0.366
# p_e,h,t-1      1.0913      0.226      4.828      0.000       0.636       1.547
# price_diff     0.4417      0.073      6.063      0.000       0.295       0.588
# constant       0.0200      0.013      1.598      0.117      -0.005       0.045
# ==============================================================================
# Omnibus:                        1.054   Durbin-Watson:                   2.336
# Prob(Omnibus):                  0.590   Jarque-Bera (JB):                0.948
# Skew:                           0.329   Prob(JB):                        0.622
# Kurtosis:                       2.799   Cond. No.                     1.87e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.87e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ## Fundamentalist Trader Positive

# %%
# Step 1: Load the Excel file
# Replace 'your_file.xlsx' with the actual filename of your Excel file
file_path = '..\Linear Regression\Fundamentalist Trader Positive.xlsx'  # Update this with your file path
data = pd.read_excel(file_path)
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\L'
# <>:3: SyntaxWarning: invalid escape sequence '\L'
# C:\Users\Sidney\AppData\Local\Temp\ipykernel_57280\3111825808.py:3: SyntaxWarning: invalid escape sequence '\L'
#   file_path = '..\Linear Regression\Fundamentalist Trader Positive.xlsx'  # Update this with your file path

# %%
# Step 2: Aggregate data by time step to calculate mean predicted and actual prices
aggregated_data = data.groupby('time_step').agg({
    'predicted_price': 'mean',      # Mean predicted price
    'actual_price': 'mean'    # Mean actual price
}).reset_index()

# Step 3: Create lagged variables
aggregated_data['p_t-1'] = aggregated_data['actual_price'].shift(1)
aggregated_data['p_t-2'] = aggregated_data['actual_price'].shift(2)
aggregated_data['p_e,h,t-1'] = aggregated_data['predicted_price'].shift(1)

# Step 4: Calculate price difference
aggregated_data['price_diff'] = aggregated_data['p_t-1'] - aggregated_data['p_t-2']

# Step 5: Drop rows with missing values due to lagging
aggregated_data = aggregated_data.dropna()

# Step 6: Prepare regression variables
X = aggregated_data[['p_t-1', 'p_e,h,t-1', 'price_diff']]  # Independent variables
X['constant'] = 60  # Add the constant term (60)
y = aggregated_data['predicted_price']  # Dependent variable (mean predicted price)

# Step 7: Add intercept for regression
X = sm.add_constant(X)

# Just to make sur that all columns in X are numeric 
X = X.apply(pd.to_numeric, errors='coerce')

# Ensure y is numeric as well
y = pd.to_numeric(y, errors='coerce')

# Step 8: Run the regression
model = sm.OLS(y, X).fit()
# Out:
# C:\Users\Sidney\AppData\Local\Temp\ipykernel_57280\81247018.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['constant'] = 60  # Add the constant term (60)

# %%
# Step 9: Output the regression results
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        predicted_price   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 9.125e+04
# Date:                Wed, 05 Feb 2025   Prob (F-statistic):           1.83e-83
# Time:                        01:17:44   Log-Likelihood:                 65.035
# No. Observations:                  48   AIC:                            -122.1
# Df Residuals:                      44   BIC:                            -114.6
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# p_t-1         -0.4016      0.135     -2.985      0.005      -0.673      -0.130
# p_e,h,t-1      1.3754      0.129     10.672      0.000       1.116       1.635
# price_diff     0.9141      0.052     17.494      0.000       0.809       1.019
# constant       0.0269      0.006      4.354      0.000       0.014       0.039
# ==============================================================================
# Omnibus:                        3.004   Durbin-Watson:                   2.151
# Prob(Omnibus):                  0.223   Jarque-Bera (JB):                2.061
# Skew:                          -0.288   Prob(JB):                        0.357
# Kurtosis:                       3.836   Cond. No.                     2.08e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.08e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ## Aggressive Speculator Negative

# %%
# Step 1: Load the Excel file
# Replace 'your_file.xlsx' with the actual filename of your Excel file
file_path = '..\Linear Regression\Aggressive Speculator Negative.csv'  # Update this with your file path
data = pd.read_csv(file_path)
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\L'
# <>:3: SyntaxWarning: invalid escape sequence '\L'
# C:\Users\Sidney\AppData\Local\Temp\ipykernel_41060\3846225709.py:3: SyntaxWarning: invalid escape sequence '\L'
#   file_path = '..\Linear Regression\Aggressive Speculator Negative.csv'  # Update this with your file path

# %%
# Step 2: Aggregate data by time step to calculate mean predicted and actual prices
aggregated_data = data.groupby('time_step').agg({
    'mean_predicted_price': 'mean',      # Mean predicted price
    'mean_actual_price': 'mean'    # Mean actual price
}).reset_index()

# Step 3: Create lagged variables
aggregated_data['p_t-1'] = aggregated_data['mean_actual_price'].shift(1)
aggregated_data['p_t-2'] = aggregated_data['mean_actual_price'].shift(2)
aggregated_data['p_e,h,t-1'] = aggregated_data['mean_predicted_price'].shift(1)

# Step 4: Calculate price difference
aggregated_data['price_diff'] = aggregated_data['p_t-1'] - aggregated_data['p_t-2']

# Step 5: Drop rows with missing values due to lagging
aggregated_data = aggregated_data.dropna()

# Step 6: Prepare regression variables
X = aggregated_data[['p_t-1', 'p_e,h,t-1', 'price_diff']]  # Independent variables
X['constant'] = 60  # Add the constant term (60)
y = aggregated_data['mean_predicted_price']  # Dependent variable (mean predicted price)

# Step 7: Add intercept for regression
X = sm.add_constant(X)

# Just to make sur that all columns in X are numeric 
X = X.apply(pd.to_numeric, errors='coerce')

# Ensure y is numeric as well
y = pd.to_numeric(y, errors='coerce')

# Step 8: Run the regression
model = sm.OLS(y, X).fit()
# Out:
# C:\Users\Sidney\AppData\Local\Temp\ipykernel_41060\3450957014.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['constant'] = 60  # Add the constant term (60)

# %%
# Step 9: Output the regression results
print(model.summary())
# Out:
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     mean_predicted_price   R-squared:                       0.812
# Model:                              OLS   Adj. R-squared:                  0.799
# Method:                   Least Squares   F-statistic:                     63.31
# Date:                  Wed, 19 Feb 2025   Prob (F-statistic):           5.29e-16
# Time:                          19:03:08   Log-Likelihood:                -103.05
# No. Observations:                    48   AIC:                             214.1
# Df Residuals:                        44   BIC:                             221.6
# Df Model:                             3
# Covariance Type:              nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# p_t-1          2.8639      3.968      0.722      0.474      -5.133      10.861
# p_e,h,t-1      3.6424      3.778      0.964      0.340      -3.971      11.256
# price_diff     0.4061      0.071      5.729      0.000       0.263       0.549
# constant      -5.4720      7.744     -0.707      0.484     -21.079      10.135
# ==============================================================================
# Omnibus:                        3.946   Durbin-Watson:                   1.784
# Prob(Omnibus):                  0.139   Jarque-Bera (JB):                2.833
# Skew:                          -0.530   Prob(JB):                        0.243
# Kurtosis:                       3.540   Cond. No.                     3.26e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.26e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ## Momentum Trader Negative

# %%
# Step 1: Load the Excel file
# Replace 'your_file.xlsx' with the actual filename of your Excel file
file_path = '..\Linear Regression\Momentum Trader Negative.csv'  # Update this with your file path
data = pd.read_csv(file_path)
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\L'
# <>:3: SyntaxWarning: invalid escape sequence '\L'
# C:\Users\Sidney\AppData\Local\Temp\ipykernel_41060\2482349651.py:3: SyntaxWarning: invalid escape sequence '\L'
#   file_path = '..\Linear Regression\Momentum Trader Negative.csv'  # Update this with your file path

# %%
# Step 2: Aggregate data by time step to calculate mean predicted and actual prices
aggregated_data = data.groupby('time_step').agg({
    'mean_predicted_price': 'mean',      # Mean predicted price
    'mean_actual_price': 'mean'    # Mean actual price
}).reset_index()

# Step 3: Create lagged variables
aggregated_data['p_t-1'] = aggregated_data['mean_actual_price'].shift(1)
aggregated_data['p_t-2'] = aggregated_data['mean_actual_price'].shift(2)
aggregated_data['p_e,h,t-1'] = aggregated_data['mean_predicted_price'].shift(1)

# Step 4: Calculate price difference
aggregated_data['price_diff'] = aggregated_data['p_t-1'] - aggregated_data['p_t-2']

# Step 5: Drop rows with missing values due to lagging
aggregated_data = aggregated_data.dropna()

# Step 6: Prepare regression variables
X = aggregated_data[['p_t-1', 'p_e,h,t-1', 'price_diff']]  # Independent variables
X['constant'] = 60  # Add the constant term (60)
y = aggregated_data['mean_predicted_price']  # Dependent variable (mean predicted price)

# Step 7: Add intercept for regression
X = sm.add_constant(X)

# Just to make sur that all columns in X are numeric 
X = X.apply(pd.to_numeric, errors='coerce')

# Ensure y is numeric as well
y = pd.to_numeric(y, errors='coerce')

# Step 8: Run the regression
model = sm.OLS(y, X).fit()
# Out:
# C:\Users\Sidney\AppData\Local\Temp\ipykernel_41060\3450957014.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['constant'] = 60  # Add the constant term (60)

# %%
# Step 9: Output the regression results
print(model.summary())
# Out:
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     mean_predicted_price   R-squared:                       0.962
# Model:                              OLS   Adj. R-squared:                  0.960
# Method:                   Least Squares   F-statistic:                     376.1
# Date:                  Wed, 19 Feb 2025   Prob (F-statistic):           2.30e-31
# Time:                          19:06:52   Log-Likelihood:                -54.177
# No. Observations:                    48   AIC:                             116.4
# Df Residuals:                        44   BIC:                             123.8
# Df Model:                             3
# Covariance Type:              nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# p_t-1         -0.6362      1.656     -0.384      0.703      -3.974       2.702
# p_e,h,t-1     -1.9110      1.592     -1.200      0.236      -5.120       1.298
# price_diff    -0.2032      0.139     -1.462      0.151      -0.483       0.077
# constant       3.5533      3.236      1.098      0.278      -2.968      10.075
# ==============================================================================
# Omnibus:                       20.633   Durbin-Watson:                   1.675
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               49.563
# Skew:                          -1.065   Prob(JB):                     1.73e-11
# Kurtosis:                       7.500   Cond. No.                     3.65e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.65e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ## Balanced Decision-Maker Negative

# %%
# Step 1: Load the Excel file
# Replace 'your_file.xlsx' with the actual filename of your Excel file
file_path = '..\Linear Regression\Balanced Decision-Maker Negative.csv'  # Update this with your file path
data = pd.read_csv(file_path)
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\L'
# <>:3: SyntaxWarning: invalid escape sequence '\L'
# C:\Users\Sidney\AppData\Local\Temp\ipykernel_41060\438443183.py:3: SyntaxWarning: invalid escape sequence '\L'
#   file_path = '..\Linear Regression\Balanced Decision-Maker Negative.csv'  # Update this with your file path

# %%
# Step 2: Aggregate data by time step to calculate mean predicted and actual prices
aggregated_data = data.groupby('time_step').agg({
    'mean_predicted_price': 'mean',      # Mean predicted price
    'mean_actual_price': 'mean'    # Mean actual price
}).reset_index()

# Step 3: Create lagged variables
aggregated_data['p_t-1'] = aggregated_data['mean_actual_price'].shift(1)
aggregated_data['p_t-2'] = aggregated_data['mean_actual_price'].shift(2)
aggregated_data['p_e,h,t-1'] = aggregated_data['mean_predicted_price'].shift(1)

# Step 4: Calculate price difference
aggregated_data['price_diff'] = aggregated_data['p_t-1'] - aggregated_data['p_t-2']

# Step 5: Drop rows with missing values due to lagging
aggregated_data = aggregated_data.dropna()

# Step 6: Prepare regression variables
X = aggregated_data[['p_t-1', 'p_e,h,t-1', 'price_diff']]  # Independent variables
X['constant'] = 60  # Add the constant term (60)
y = aggregated_data['mean_predicted_price']  # Dependent variable (mean predicted price)

# Step 7: Add intercept for regression
X = sm.add_constant(X)

# Just to make sur that all columns in X are numeric 
X = X.apply(pd.to_numeric, errors='coerce')

# Ensure y is numeric as well
y = pd.to_numeric(y, errors='coerce')

# Step 8: Run the regression
model = sm.OLS(y, X).fit()
# Out:
# C:\Users\Sidney\AppData\Local\Temp\ipykernel_41060\3450957014.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['constant'] = 60  # Add the constant term (60)

# %%
# Step 9: Output the regression results
print(model.summary())
# Out:
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     mean_predicted_price   R-squared:                       0.982
# Model:                              OLS   Adj. R-squared:                  0.981
# Method:                   Least Squares   F-statistic:                     803.1
# Date:                  Wed, 19 Feb 2025   Prob (F-statistic):           2.03e-38
# Time:                          19:09:41   Log-Likelihood:                -22.802
# No. Observations:                    48   AIC:                             53.60
# Df Residuals:                        44   BIC:                             61.09
# Df Model:                             3
# Covariance Type:              nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# p_t-1          2.0342      0.770      2.643      0.011       0.483       3.585
# p_e,h,t-1      1.6708      0.727      2.297      0.026       0.205       3.137
# price_diff     0.3185      0.108      2.948      0.005       0.101       0.536
# constant      -2.7021      1.480     -1.826      0.075      -5.685       0.281
# ==============================================================================
# Omnibus:                       11.446   Durbin-Watson:                   2.230
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):               35.874
# Skew:                           0.027   Prob(JB):                     1.62e-08
# Kurtosis:                       7.235   Cond. No.                     3.21e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.21e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ## Market Analyst Negative

# %%
# Step 1: Load the Excel file
# Replace 'your_file.xlsx' with the actual filename of your Excel file
file_path = '..\Linear Regression\Market Analyst Negative.csv'  # Update this with your file path
data = pd.read_csv(file_path)
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\L'
# <>:3: SyntaxWarning: invalid escape sequence '\L'
# C:\Users\Sidney\AppData\Local\Temp\ipykernel_41060\3288607115.py:3: SyntaxWarning: invalid escape sequence '\L'
#   file_path = '..\Linear Regression\Market Analyst Negative.csv'  # Update this with your file path

# %%
# Step 2: Aggregate data by time step to calculate mean predicted and actual prices
aggregated_data = data.groupby('time_step').agg({
    'mean_predicted_price': 'mean',      # Mean predicted price
    'mean_actual_price': 'mean'    # Mean actual price
}).reset_index()

# Step 3: Create lagged variables
aggregated_data['p_t-1'] = aggregated_data['mean_actual_price'].shift(1)
aggregated_data['p_t-2'] = aggregated_data['mean_actual_price'].shift(2)
aggregated_data['p_e,h,t-1'] = aggregated_data['mean_predicted_price'].shift(1)

# Step 4: Calculate price difference
aggregated_data['price_diff'] = aggregated_data['p_t-1'] - aggregated_data['p_t-2']

# Step 5: Drop rows with missing values due to lagging
aggregated_data = aggregated_data.dropna()

# Step 6: Prepare regression variables
X = aggregated_data[['p_t-1', 'p_e,h,t-1', 'price_diff']]  # Independent variables
X['constant'] = 60  # Add the constant term (60)
y = aggregated_data['mean_predicted_price']  # Dependent variable (mean predicted price)

# Step 7: Add intercept for regression
X = sm.add_constant(X)

# Just to make sur that all columns in X are numeric 
X = X.apply(pd.to_numeric, errors='coerce')

# Ensure y is numeric as well
y = pd.to_numeric(y, errors='coerce')

# Step 8: Run the regression
model = sm.OLS(y, X).fit()
# Out:
# C:\Users\Sidney\AppData\Local\Temp\ipykernel_41060\3450957014.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['constant'] = 60  # Add the constant term (60)

# %%
# Step 9: Output the regression results
print(model.summary())
# Out:
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     mean_predicted_price   R-squared:                       0.989
# Model:                              OLS   Adj. R-squared:                  0.988
# Method:                   Least Squares   F-statistic:                     1272.
# Date:                  Wed, 19 Feb 2025   Prob (F-statistic):           9.60e-43
# Time:                          19:09:55   Log-Likelihood:                -17.608
# No. Observations:                    48   AIC:                             43.22
# Df Residuals:                        44   BIC:                             50.70
# Df Model:                             3
# Covariance Type:              nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# p_t-1         -0.0885      0.615     -0.144      0.886      -1.328       1.151
# p_e,h,t-1     -1.4375      0.616     -2.334      0.024      -2.679      -0.196
# price_diff    -0.2300      0.128     -1.802      0.078      -0.487       0.027
# constant       2.5323      1.204      2.104      0.041       0.107       4.958
# ==============================================================================
# Omnibus:                       22.174   Durbin-Watson:                   1.946
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               80.388
# Skew:                          -0.940   Prob(JB):                     3.50e-18
# Kurtosis:                       9.055   Cond. No.                     2.91e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.91e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ## Contrarian Investor Negative

# %%
# Step 1: Load the Excel file
# Replace 'your_file.xlsx' with the actual filename of your Excel file
file_path = '..\Linear Regression\Contrarian Investor Negative.csv'  # Update this with your file path
data = pd.read_csv(file_path)
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\L'
# <>:3: SyntaxWarning: invalid escape sequence '\L'
# C:\Users\Sidney\AppData\Local\Temp\ipykernel_41060\1758470328.py:3: SyntaxWarning: invalid escape sequence '\L'
#   file_path = '..\Linear Regression\Contrarian Investor Negative.csv'  # Update this with your file path

# %%
# Step 2: Aggregate data by time step to calculate mean predicted and actual prices
aggregated_data = data.groupby('time_step').agg({
    'mean_predicted_price': 'mean',      # Mean predicted price
    'mean_actual_price': 'mean'    # Mean actual price
}).reset_index()

# Step 3: Create lagged variables
aggregated_data['p_t-1'] = aggregated_data['mean_actual_price'].shift(1)
aggregated_data['p_t-2'] = aggregated_data['mean_actual_price'].shift(2)
aggregated_data['p_e,h,t-1'] = aggregated_data['mean_predicted_price'].shift(1)

# Step 4: Calculate price difference
aggregated_data['price_diff'] = aggregated_data['p_t-1'] - aggregated_data['p_t-2']

# Step 5: Drop rows with missing values due to lagging
aggregated_data = aggregated_data.dropna()

# Step 6: Prepare regression variables
X = aggregated_data[['p_t-1', 'p_e,h,t-1', 'price_diff']]  # Independent variables
X['constant'] = 60  # Add the constant term (60)
y = aggregated_data['mean_predicted_price']  # Dependent variable (mean predicted price)

# Step 7: Add intercept for regression
X = sm.add_constant(X)

# Just to make sur that all columns in X are numeric 
X = X.apply(pd.to_numeric, errors='coerce')

# Ensure y is numeric as well
y = pd.to_numeric(y, errors='coerce')

# Step 8: Run the regression
model = sm.OLS(y, X).fit()
# Out:
# C:\Users\Sidney\AppData\Local\Temp\ipykernel_41060\3450957014.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['constant'] = 60  # Add the constant term (60)

# %%
# Step 9: Output the regression results
print(model.summary())
# Out:
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     mean_predicted_price   R-squared:                       0.922
# Model:                              OLS   Adj. R-squared:                  0.917
# Method:                   Least Squares   F-statistic:                     173.0
# Date:                  Wed, 19 Feb 2025   Prob (F-statistic):           2.27e-24
# Time:                          19:11:07   Log-Likelihood:                -40.575
# No. Observations:                    48   AIC:                             89.15
# Df Residuals:                        44   BIC:                             96.63
# Df Model:                             3
# Covariance Type:              nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# p_t-1          0.8630      1.093      0.789      0.434      -1.341       3.067
# p_e,h,t-1      1.4388      1.039      1.384      0.173      -0.656       3.534
# price_diff     0.3360      0.050      6.780      0.000       0.236       0.436
# constant      -1.3030      2.133     -0.611      0.544      -5.601       2.995
# ==============================================================================
# Omnibus:                        3.162   Durbin-Watson:                   1.820
# Prob(Omnibus):                  0.206   Jarque-Bera (JB):                2.689
# Skew:                          -0.010   Prob(JB):                        0.261
# Kurtosis:                       4.159   Cond. No.                     3.20e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.2e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ## Fundamentalist Trader Negative

# %%
# Step 1: Load the Excel file
# Replace 'your_file.xlsx' with the actual filename of your Excel file
file_path = '..\Linear Regression\Fundamentalist Trader Negative.csv'  # Update this with your file path
data = pd.read_csv(file_path)
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\L'
# <>:3: SyntaxWarning: invalid escape sequence '\L'
# C:\Users\Sidney\AppData\Local\Temp\ipykernel_3904\2755748172.py:3: SyntaxWarning: invalid escape sequence '\L'
#   file_path = '..\Linear Regression\Fundamentalist Trader Negative.csv'  # Update this with your file path

# %%
# Step 2: Aggregate data by time step to calculate mean predicted and actual prices
aggregated_data = data.groupby('time_step').agg({
    'mean_predicted_price': 'mean',      # Mean predicted price
    'mean_actual_price': 'mean'    # Mean actual price
}).reset_index()

# Step 3: Create lagged variables
aggregated_data['p_t-1'] = aggregated_data['mean_actual_price'].shift(1)
aggregated_data['p_t-2'] = aggregated_data['mean_actual_price'].shift(2)
aggregated_data['p_e,h,t-1'] = aggregated_data['mean_predicted_price'].shift(1)

# Step 4: Calculate price difference
aggregated_data['price_diff'] = aggregated_data['p_t-1'] - aggregated_data['p_t-2']

# Step 5: Drop rows with missing values due to lagging
aggregated_data = aggregated_data.dropna()

# Step 6: Prepare regression variables
X = aggregated_data[['p_t-1', 'p_e,h,t-1', 'price_diff']]  # Independent variables
X['constant'] = 60  # Add the constant term (60)
y = aggregated_data['mean_predicted_price']  # Dependent variable (mean predicted price)

# Step 7: Add intercept for regression
X = sm.add_constant(X)

# Just to make sur that all columns in X are numeric 
X = X.apply(pd.to_numeric, errors='coerce')

# Ensure y is numeric as well
y = pd.to_numeric(y, errors='coerce')

# Step 8: Run the regression
model = sm.OLS(y, X).fit()
# Out:
# C:\Users\Sidney\AppData\Local\Temp\ipykernel_3904\3450957014.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['constant'] = 60  # Add the constant term (60)

# %%
# Step 9: Output the regression results
print(model.summary())
# Out:
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     mean_predicted_price   R-squared:                       0.899
# Model:                              OLS   Adj. R-squared:                  0.892
# Method:                   Least Squares   F-statistic:                     130.1
# Date:                  Thu, 03 Apr 2025   Prob (F-statistic):           6.85e-22
# Time:                          11:48:17   Log-Likelihood:                 3.7231
# No. Observations:                    48   AIC:                            0.5538
# Df Residuals:                        44   BIC:                             8.039
# Df Model:                             3
# Covariance Type:              nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# p_t-1         -0.2338      0.522     -0.448      0.656      -1.285       0.817
# p_e,h,t-1      0.0175      0.517      0.034      0.973      -1.025       1.060
# price_diff     0.3815      0.040      9.487      0.000       0.300       0.463
# constant       1.2098      1.033      1.171      0.248      -0.872       3.291
# ==============================================================================
# Omnibus:                        5.012   Durbin-Watson:                   0.952
# Prob(Omnibus):                  0.082   Jarque-Bera (JB):                4.070
# Skew:                          -0.485   Prob(JB):                        0.131
# Kurtosis:                       4.045   Cond. No.                     3.89e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.89e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
