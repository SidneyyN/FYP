# %%
import sys

sys.path += ["../src/"]
from utils import *

# %% [markdown]
# # Positive Feedback

# %% [markdown]
# ## High-Volatility Setup (NO CONSTRAINT)

# %%
plot_experiment_results("../results/experiments/experiment_batch_20250226_121541_High-volatility/consolidated_results.csv")

# %%
plot_time_series("../results/experiments/experiment_batch_20250226_121541_High-volatility/consolidated_results.csv")

# %% [markdown]
# ## High-Volatility Setup (WITH CONSTRAINT)

# %%
plot_experiment_results("../results/experiments/experiment_batch_20250308_153210_Pos_High-Vol_Constraint/consolidated_results.csv")

# %%
plot_time_series("../results/experiments/experiment_batch_20250308_153210_Pos_High-Vol_Constraint/consolidated_results.csv")

# %% [markdown]
# ## High-Volatility Setup (No Constraints 6 Agents)

# %%
plot_experiment_results("../results/experiments/experiment_batch_20250427_123547_High-volatility/consolidated_results.csv")

# %%
plot_time_series("../results/experiments/experiment_batch_20250427_123547_High-volatility/consolidated_results.csv")

# %% [markdown]
# ## Stability-Focused Setup

# %%
plot_experiment_results("../results/experiments/experiment_batch_20250226_130928_Stability-Focused/consolidated_results.csv")

# %%
plot_time_series("../results/experiments/experiment_batch_20250226_130928_Stability-Focused/consolidated_results.csv")

# %% [markdown]
# # Stability-Focused Setup (6 agents)

# %%
plot_time_series("../results/experiments/experiment_batch_20250427_134105_Stability-Focused/consolidated_results.csv")

# %% [markdown]
# ## Realistic, Diverse Setup (WITHOUT CONSTRAINTS)

# %%
plot_experiment_results("../results/experiments/experiment_batch_20250226_143324_Realistic/consolidated_results.csv")

# %%
plot_time_series("../results/experiments/experiment_batch_20250226_143324_Realistic/consolidated_results.csv")

# %%
plot_rewards_only("../results/experiments/experiment_batch_20250226_143324_Realistic/consolidated_results.csv")

# %% [markdown]
# ## Realistic, Diverse Setup (WITH CONSTRAINTS)

# %%
plot_experiment_results("../results/experiments/experiment_batch_20250308_161229_Pos_Realistic_Constraint/consolidated_results.csv")

# %%
plot_time_series("../results/experiments/experiment_batch_20250308_161229_Pos_Realistic_Constraint/consolidated_results.csv")

# %% [markdown]
# ## Aggressive Speculator

# %%
plot_time_series("../Linear Regression/Aggressive Speculator Positive.xlsx")

# %% [markdown]
# ## Momentum Trader

# %%
plot_time_series("../Linear Regression/Momentum Trader Positive.xlsx")

# %% [markdown]
# ## Balanced Decision-Maker

# %%
plot_time_series("../Linear Regression/Balanced Decision-Maker Positive.xlsx")

# %% [markdown]
# ## Market Analyst

# %%
plot_time_series("../Linear Regression/Market Analyst Positive.xlsx")

# %% [markdown]
# ## Contrarian Investor

# %%
plot_time_series("../Linear Regression/Contrarian Investor Positive.xlsx")

# %% [markdown]
# ## Fundamentalist Trader

# %%
plot_time_series("../Linear Regression/Fundamentalist Trader Positive.xlsx")

# %% [markdown]
# # Negative Feedback

# %% [markdown]
# ## High-Volatility Setup

# %%
plot_experiment_results("../results/experiments/experiment_batch_20250308_201223_Neg_High-Volatility_Constraint/consolidated_results.csv")

# %%
plot_time_series("../results/experiments/experiment_batch_20250308_201223_Neg_High-Volatility_Constraint/consolidated_results.csv")

# %% [markdown]
# ## High-Volatility Setup (6 agents)

# %%
plot_time_series("../results/experiments/experiment_batch_20250427_004339_High-Volatility_Negative/consolidated_results.csv")

# %% [markdown]
# ## Stability-Focused Setup

# %%
plot_experiment_results("../results/experiments/experiment_batch_20250308_205627_Neg_Stability-Focused/consolidated_results.csv")

# %%
plot_time_series("../results/experiments/experiment_batch_20250308_205627_Neg_Stability-Focused/consolidated_results.csv")

# %% [markdown]
# ## Stability-Focused Setup (6 Agents)

# %%
plot_time_series("../results/experiments/experiment_batch_20250427_013541_Stability-Focused_Negative/consolidated_results.csv")

# %% [markdown]
# ## Realistic, Diverse Setup

# %%
plot_experiment_results("../results/experiments/experiment_batch_20250308_213719_Neg_Realistic_Constraint/consolidated_results.csv")

# %%
plot_time_series("../results/experiments/experiment_batch_20250308_213719_Neg_Realistic_Constraint/consolidated_results.csv")

# %% [markdown]
# ## Aggressive Speculators

# %%
plot_time_series("../Linear Regression/Aggressive Speculator Negative.csv")

# %% [markdown]
# ## Momentum Trader

# %%
plot_time_series("../Linear Regression/Momentum Trader Negative.csv")

# %% [markdown]
# ## Balanced Decision-Maker

# %%
plot_time_series("../Linear Regression/Balanced Decision-Maker Negative.csv")

# %% [markdown]
# ## Market Analyst

# %%
plot_time_series("../Linear Regression/Market Analyst Negative.csv")

# %% [markdown]
# ## Contrarian Investor

# %%
plot_time_series("../Linear Regression/Contrarian Investor Negative.csv")

# %% [markdown]
# ## Fundamentalist Trader

# %%
plot_time_series("../Linear Regression/Fundamentalist Trader Negative.csv")
