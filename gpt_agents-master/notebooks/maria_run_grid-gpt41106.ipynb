# %%
import openai
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
import re
import time
from openai import OpenAI
import json
import pickle
import pandas as pd
import os

sys.path += ['../src/']

#from model import *
import model as mod
import model
from utils import *
from itertools import product

# %%
path_exp = '../results/experiments/'

# %%
openai.__version__
# Out:
# '1.9.0'

# %%
# set simulation parameters (fixed)
noise_mean = 0
noise_sd = 1/4
instruction_type = 'original_30-50w'
n_agents = 6
n_steps = 50
gpt_model= "gpt-4-1106-preview"#"gpt-4"

# %% [markdown]
# ## Run 14 May memory 7 and 10

# %%
#grid parameters

# Define the lists
memory_values = [7, 10]
temperature_values = [1.0]
feedback_values = ['pos', 'neg']
expmnt_nums = [1, 2, 3]

# Generate all combinations
combinations = list(product(memory_values, temperature_values, feedback_values, expmnt_nums))

# Create a DataFrame from the combinations
df = pd.DataFrame(combinations, columns=['memory', 'temperature', 'feedback', 'expmnt_num'])

# %%
for i in range(df.shape[0]):

    memory = df["memory"].iloc[i]
    temperature = df["temperature"].iloc[i]
    feedback = df["feedback"].iloc[i]
    expmnt_num = df["expmnt_num"].iloc[i]

    
    expmnt_num = check_existing_file(path_exp, expmnt_num, feedback, instruction_type, temperature, memory, n_steps, n_agents, gpt_model)
    seed = expmnt_num
    np.random.seed(seed)

    p, pe, rewards, messages_list  = mod.run_experiment(seed,\
                    expmnt_num, noise_mean, noise_sd, temperature, memory=memory, gpt_model=gpt_model, n_steps=n_steps, n_agents=n_agents,
                    feedback=feedback, instruction_type=instruction_type, prints_on=False,\
                    save_res_bool=True, path_exp=path_exp)
# Out:
# File expmnt_results_pos_original_30-50w_num_1_temp_1-0_memory_7_ntime_50_nagents_6_model_gpt-4-1106-preview.csv does not exist. Safe to proceed.
# File expmnt_results_pos_original_30-50w_num_2_temp_1-0_memory_7_ntime_50_nagents_6_model_gpt-4-1106-preview.csv does not exist. Safe to proceed.
# File expmnt_results_pos_original_30-50w_num_3_temp_1-0_memory_7_ntime_50_nagents_6_model_gpt-4-1106-preview.csv does not exist. Safe to proceed.
# File expmnt_results_neg_original_30-50w_num_1_temp_1-0_memory_7_ntime_50_nagents_6_model_gpt-4-1106-preview.csv does not exist. Safe to proceed.
# File expmnt_results_neg_original_30-50w_num_2_temp_1-0_memory_7_ntime_50_nagents_6_model_gpt-4-1106-preview.csv does not exist. Safe to proceed.
# File expmnt_results_neg_original_30-50w_num_3_temp_1-0_memory_7_ntime_50_nagents_6_model_gpt-4-1106-preview.csv does not exist. Safe to proceed.
# File expmnt_results_pos_original_30-50w_num_1_temp_1-0_memory_10_ntime_50_nagents_6_model_gpt-4-1106-preview.csv does not exist. Safe to proceed.
# File expmnt_results_pos_original_30-50w_num_2_temp_1-0_memory_10_ntime_50_nagents_6_model_gpt-4-1106-preview.csv does not exist. Safe to proceed.
# File expmnt_results_pos_original_30-50w_num_3_temp_1-0_memory_10_ntime_50_nagents_6_model_gpt-4-1106-preview.csv does not exist. Safe to proceed.
# File expmnt_results_neg_original_30-50w_num_1_temp_1-0_memory_10_ntime_50_nagents_6_model_gpt-4-1106-preview.csv does not exist. Safe to proceed.
# File expmnt_results_neg_original_30-50w_num_2_temp_1-0_memory_10_ntime_50_nagents_6_model_gpt-4-1106-preview.csv does not exist. Safe to proceed.
# File expmnt_results_neg_original_30-50w_num_3_temp_1-0_memory_10_ntime_50_nagents_6_model_gpt-4-1106-preview.csv does not exist. Safe to proceed.

# %% [markdown]
# ### Previous runs

# %%
#grid parameters

# Define the lists
memory_values = [1, 3, 5]
temperature_values = [0.3, 0.7, 1.0]
feedback_values = ['pos', 'neg']
expmnt_nums = [1, 2, 3]

# Generate all combinations
combinations = list(product(memory_values, temperature_values, feedback_values, expmnt_nums))

# Create a DataFrame from the combinations
df = pd.DataFrame(combinations, columns=['memory', 'temperature', 'feedback', 'expmnt_num'])

# %%
gpt_model
# Out:
# 'gpt-4-1106-preview'

# %% [markdown]
# # Run pos_original_30-50w_num_2_temp_1-0_memory_5

# %%
memory_values = [5]
temperature_values = [1.0]
feedback_values = ['pos', 'neg']
expmnt_nums = [1, 2, 3]

# %%
memory = 5
temperature = 1
feedback_values = ['pos', 'neg']
expmnt_nums = [1, 2, 3]

for feedback in feedback_values:
    for expmnt_num in expmnt_nums:

        expmnt_num = check_existing_file(path_exp, expmnt_num, feedback, instruction_type, temperature, memory, n_steps, n_agents, gpt_model)
        seed = expmnt_num
        np.random.seed(seed)
            
        p, pe, rewards, messages_list  = mod.run_experiment(seed,\
                        expmnt_num, noise_mean, noise_sd, temperature, memory=memory, gpt_model=gpt_model, n_steps=n_steps, n_agents=n_agents,
                        feedback=feedback, instruction_type=instruction_type, prints_on=False,\
                        save_res_bool=True, path_exp=path_exp)
# Out:
# File expmnt_results_pos_original_30-50w_num_1_temp_1_memory_5_ntime_50_nagents_6_model_gpt-4-1106-preview.csv does not exist. Safe to proceed.
# File expmnt_results_pos_original_30-50w_num_2_temp_1_memory_5_ntime_50_nagents_6_model_gpt-4-1106-preview.csv does not exist. Safe to proceed.
# File expmnt_results_pos_original_30-50w_num_3_temp_1_memory_5_ntime_50_nagents_6_model_gpt-4-1106-preview.csv does not exist. Safe to proceed.
# File expmnt_results_neg_original_30-50w_num_1_temp_1_memory_5_ntime_50_nagents_6_model_gpt-4-1106-preview.csv does not exist. Safe to proceed.
# File expmnt_results_neg_original_30-50w_num_2_temp_1_memory_5_ntime_50_nagents_6_model_gpt-4-1106-preview.csv does not exist. Safe to proceed.
# File expmnt_results_neg_original_30-50w_num_3_temp_1_memory_5_ntime_50_nagents_6_model_gpt-4-1106-preview.csv does not exist. Safe to proceed.

# %% [markdown]
# ## Run 17 April

# %%
for i in range(df.shape[0]):

    memory = df["memory"].iloc[i]
    temperature = df["temperature"].iloc[i]
    feedback = df["feedback"].iloc[i]
    expmnt_num = df["expmnt_num"].iloc[i]

    # Since we already ran the below in the quick test
    if memory == 3 and temperature == 0.7:
        pass

    else:
        expmnt_num = check_existing_file(path_exp, expmnt_num, feedback, instruction_type, temperature, memory, n_steps, n_agents, gpt_model)
        seed = expmnt_num
        np.random.seed(seed)
    
        p, pe, rewards, messages_list  = mod.run_experiment(seed,\
                        expmnt_num, noise_mean, noise_sd, temperature, memory=memory, gpt_model=gpt_model, n_steps=n_steps, n_agents=n_agents,
                        feedback=feedback, instruction_type=instruction_type, prints_on=False,\
                        save_res_bool=True, path_exp=path_exp)
# Out:
# File expmnt_results_pos_original_30-50w_num_1_temp_0-3_memory_1_ntime_50_nagents_6_model_gpt-4-1106-preview.csv does not exist. Safe to proceed.
# File expmnt_results_pos_original_30-50w_num_2_temp_0-3_memory_1_ntime_50_nagents_6_model_gpt-4-1106-preview.csv does not exist. Safe to proceed.
# File expmnt_results_pos_original_30-50w_num_3_temp_0-3_memory_1_ntime_50_nagents_6_model_gpt-4-1106-preview.csv does not exist. Safe to proceed.
# File expmnt_results_neg_original_30-50w_num_1_temp_0-3_memory_1_ntime_50_nagents_6_model_gpt-4-1106-preview.csv does not exist. Safe to proceed.
# File expmnt_results_neg_original_30-50w_num_2_temp_0-3_memory_1_ntime_50_nagents_6_model_gpt-4-1106-preview.csv does not exist. Safe to proceed.
# File expmnt_results_neg_original_30-50w_num_3_temp_0-3_memory_1_ntime_50_nagents_6_model_gpt-4-1106-preview.csv does not exist. Safe to proceed.
# File expmnt_results_pos_original_30-50w_num_1_temp_0-7_memory_1_ntime_50_nagents_6_model_gpt-4-1106-preview.csv does not exist. Safe to proceed.
# File expmnt_results_pos_original_30-50w_num_2_temp_0-7_memory_1_ntime_50_nagents_6_model_gpt-4-1106-preview.csv does not exist. Safe to proceed.
# File expmnt_results_pos_original_30-50w_num_3_temp_0-7_memory_1_ntime_50_nagents_6_model_gpt-4-1106-preview.csv does not exist. Safe to proceed.
# File expmnt_results_neg_original_30-50w_num_1_temp_0-7_memory_1_ntime_50_nagents_6_model_gpt-4-1106-preview.csv does not exist. Safe to proceed.
# File expmnt_results_neg_original_30-50w_num_2_temp_0-7_memory_1_ntime_50_nagents_6_model_gpt-4-1106-preview.csv does not exist. Safe to proceed.
# File expmnt_results_neg_original_30-50w_num_3_temp_0-7_memory_1_ntime_50_nagents_6_model_gpt-4-1106-preview.csv does not exist. Safe to proceed.
# File expmnt_results_pos_original_30-50w_num_1_temp_1-0_memory_1_ntime_50_nagents_6_model_gpt-4-1106-preview.csv does not exist. Safe to proceed.
# File expmnt_results_pos_original_30-50w_num_2_temp_1-0_memory_1_ntime_50_nagents_6_model_gpt-4-1106-preview.csv does not exist. Safe to proceed.
# File expmnt_results_pos_original_30-50w_num_3_temp_1-0_memory_1_ntime_50_nagents_6_model_gpt-4-1106-preview.csv does not exist. Safe to proceed.
# File expmnt_results_neg_original_30-50w_num_1_temp_1-0_memory_1_ntime_50_nagents_6_model_gpt-4-1106-preview.csv does not exist. Safe to proceed.
# File expmnt_results_neg_original_30-50w_num_2_temp_1-0_memory_1_ntime_50_nagents_6_model_gpt-4-1106-preview.csv does not exist. Safe to proceed.
# File expmnt_results_neg_original_30-50w_num_3_temp_1-0_memory_1_ntime_50_nagents_6_model_gpt-4-1106-preview.csv does not exist. Safe to proceed.
# File expmnt_results_pos_original_30-50w_num_1_temp_0-3_memory_3_ntime_50_nagents_6_model_gpt-4-1106-preview.csv does not exist. Safe to proceed.
# File expmnt_results_pos_original_30-50w_num_2_temp_0-3_memory_3_ntime_50_nagents_6_model_gpt-4-1106-preview.csv does not exist. Safe to proceed.
# File expmnt_results_pos_original_30-50w_num_3_temp_0-3_memory_3_ntime_50_nagents_6_model_gpt-4-1106-preview.csv does not exist. Safe to proceed.
# File expmnt_results_neg_original_30-50w_num_1_temp_0-3_memory_3_ntime_50_nagents_6_model_gpt-4-1106-preview.csv does not exist. Safe to proceed.
# File expmnt_results_neg_original_30-50w_num_2_temp_0-3_memory_3_ntime_50_nagents_6_model_gpt-4-1106-preview.csv does not exist. Safe to proceed.
# File expmnt_results_neg_original_30-50w_num_3_temp_0-3_memory_3_ntime_50_nagents_6_model_gpt-4-1106-preview.csv does not exist. Safe to proceed.
# File expmnt_results_pos_original_30-50w_num_1_temp_1-0_memory_3_ntime_50_nagents_6_model_gpt-4-1106-preview.csv does not exist. Safe to proceed.
# File expmnt_results_pos_original_30-50w_num_2_temp_1-0_memory_3_ntime_50_nagents_6_model_gpt-4-1106-preview.csv does not exist. Safe to proceed.
# File expmnt_results_pos_original_30-50w_num_3_temp_1-0_memory_3_ntime_50_nagents_6_model_gpt-4-1106-preview.csv does not exist. Safe to proceed.
# File expmnt_results_neg_original_30-50w_num_1_temp_1-0_memory_3_ntime_50_nagents_6_model_gpt-4-1106-preview.csv does not exist. Safe to proceed.
# File expmnt_results_neg_original_30-50w_num_2_temp_1-0_memory_3_ntime_50_nagents_6_model_gpt-4-1106-preview.csv does not exist. Safe to proceed.
# File expmnt_results_neg_original_30-50w_num_3_temp_1-0_memory_3_ntime_50_nagents_6_model_gpt-4-1106-preview.csv does not exist. Safe to proceed.
# File expmnt_results_pos_original_30-50w_num_1_temp_0-3_memory_5_ntime_50_nagents_6_model_gpt-4-1106-preview.csv does not exist. Safe to proceed.
# File expmnt_results_pos_original_30-50w_num_2_temp_0-3_memory_5_ntime_50_nagents_6_model_gpt-4-1106-preview.csv does not exist. Safe to proceed.
# File expmnt_results_pos_original_30-50w_num_3_temp_0-3_memory_5_ntime_50_nagents_6_model_gpt-4-1106-preview.csv does not exist. Safe to proceed.
# File expmnt_results_neg_original_30-50w_num_1_temp_0-3_memory_5_ntime_50_nagents_6_model_gpt-4-1106-preview.csv does not exist. Safe to proceed.
# File expmnt_results_neg_original_30-50w_num_2_temp_0-3_memory_5_ntime_50_nagents_6_model_gpt-4-1106-preview.csv does not exist. Safe to proceed.
# File expmnt_results_neg_original_30-50w_num_3_temp_0-3_memory_5_ntime_50_nagents_6_model_gpt-4-1106-preview.csv does not exist. Safe to proceed.
# File expmnt_results_pos_original_30-50w_num_1_temp_0-7_memory_5_ntime_50_nagents_6_model_gpt-4-1106-preview.csv does not exist. Safe to proceed.
# File expmnt_results_pos_original_30-50w_num_2_temp_0-7_memory_5_ntime_50_nagents_6_model_gpt-4-1106-preview.csv does not exist. Safe to proceed.
# File expmnt_results_pos_original_30-50w_num_3_temp_0-7_memory_5_ntime_50_nagents_6_model_gpt-4-1106-preview.csv does not exist. Safe to proceed.
# File expmnt_results_neg_original_30-50w_num_1_temp_0-7_memory_5_ntime_50_nagents_6_model_gpt-4-1106-preview.csv does not exist. Safe to proceed.
# File expmnt_results_neg_original_30-50w_num_2_temp_0-7_memory_5_ntime_50_nagents_6_model_gpt-4-1106-preview.csv does not exist. Safe to proceed.
# File expmnt_results_neg_original_30-50w_num_3_temp_0-7_memory_5_ntime_50_nagents_6_model_gpt-4-1106-preview.csv does not exist. Safe to proceed.
# File expmnt_results_pos_original_30-50w_num_1_temp_1-0_memory_5_ntime_50_nagents_6_model_gpt-4-1106-preview.csv does not exist. Safe to proceed.
# File expmnt_results_pos_original_30-50w_num_2_temp_1-0_memory_5_ntime_50_nagents_6_model_gpt-4-1106-preview.csv does not exist. Safe to proceed.
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[10], line 17
#      14 seed = expmnt_num
#      15 np.random.seed(seed)
# ---> 17 p, pe, rewards, messages_list  = mod.run_experiment(seed,\
#      18                 expmnt_num, noise_mean, noise_sd, temperature, memory=memory, gpt_model=gpt_model, n_steps=n_steps, n_agents=n_agents,
#      19                 feedback=feedback, instruction_type=instruction_type, prints_on=False,\
#      20                 save_res_bool=True, path_exp=path_exp)
#
# File ~/Library/CloudStorage/Dropbox/gpt_agents/gpt_agents/notebooks/../src/model.py:395, in run_experiment(seed, expmnt_num, noise_mean, noise_sd, temperature, memory, gpt_model, n_steps, n_agents, feedback, instruction_type, prints_on, save_res_bool, path_exp)
#     392 agent_messages = messages_list[i] # get agents context
#     394 # get agents's answer
# --> 395 pe, continue_simulation, agent_messages = get_agent_reply(agent_messages, new_message, temperature, seed_gpt,\
#     396                                             continue_simulation, instructions_len, memory, gpt_model,\
#     397                                             new_message_json=new_message_json, prints_on=prints_on)
#     398 messages_list[i] = agent_messages # this line might be redundant but jic
#     400 if continue_simulation == False: break
#
# File ~/Library/CloudStorage/Dropbox/gpt_agents/gpt_agents/notebooks/../src/model.py:243, in get_agent_reply(agent_messages, new_message, temperature, seed_gpt, continue_simulation, instructions_len, memory, gpt_model, new_message_json, prints_on)
#     238 attempt = 0 # attempts in getting a json format answer
#     240 while continue_simulation == True and got_reply == False and attempt <= 3:
#     242     reply_dict, got_reply, error, agent_messages \
# --> 243         = get_agent_reply_and_errors(agent_messages, new_message, temperature, seed_gpt, \
#     244                                      instructions_len, memory, gpt_model, prints_on=prints_on)
#     246     if error == 'json':
#     247         attempt += 1
#
# File ~/Library/CloudStorage/Dropbox/gpt_agents/gpt_agents/notebooks/../src/model.py:224, in get_agent_reply_and_errors(agent_messages, new_message, temperature, seed_gpt, instructions_len, memory, gpt_model, prints_on)
#     221     got_reply = False
#     222     reply_dict = ''
# --> 224 return reply_dict, got_reply, error, agent_messages
#
# UnboundLocalError: cannot access local variable 'error' where it is not associated with a value

# %% [markdown]
# # Runs done below for a quick test, ommited those from grid above

# %%
for i in range(1):

    memory = 3
    temperature = 0.7
    feedback = 'pos'
    expmnt_num = df["expmnt_num"].iloc[i]
    
    expmnt_num = check_existing_file(path_exp, expmnt_num, feedback, instruction_type, temperature, memory, n_steps, n_agents, gpt_model)
    seed = expmnt_num
    np.random.seed(seed)

    p, pe, rewards, messages_list  = mod.run_experiment(seed,\
                    expmnt_num, noise_mean, noise_sd, temperature, memory=memory, gpt_model=gpt_model, n_steps=n_steps, n_agents=n_agents,
                    feedback=feedback, instruction_type=instruction_type, prints_on=False,\
                    save_res_bool=True, path_exp=path_exp)
# Out:
# File expmnt_results_pos_original_30-50w_num_1_temp_0-7_memory_3_ntime_50_nagents_6_model_gpt-4-1106-preview.csv already exists.
# Changing experiment number to 2, double check this is okay

# %%
for i in range(1):

    memory = 3
    temperature = 0.7
    feedback = 'neg'
    expmnt_num = df["expmnt_num"].iloc[i]
    
    expmnt_num = check_existing_file(path_exp, expmnt_num, feedback, instruction_type, temperature, memory, n_steps, n_agents, gpt_model)
    seed = expmnt_num
    np.random.seed(seed)

    p, pe, rewards, messages_list  = mod.run_experiment(seed,\
                    expmnt_num, noise_mean, noise_sd, temperature, memory=memory, gpt_model=gpt_model, n_steps=n_steps, n_agents=n_agents,
                    feedback=feedback, instruction_type=instruction_type, prints_on=True,\
                    save_res_bool=True, path_exp=path_exp)
# Out:
# File expmnt_results_neg_original_30-50w_num_1_temp_0-7_memory_3_ntime_50_nagents_6_model_gpt-4-1106-preview.csv already exists.
# Changing experiment number to 2, double check this is okay
#
#  Time: 0, agent: 0
#
# {'role': 'user', 'content': 'This is the first time step, give an initial price prediction'}
#
#  Time: 0, agent: 1
#
# {'role': 'user', 'content': 'This is the first time step, give an initial price prediction'}
#
#  Time: 0, agent: 2
#
# {'role': 'user', 'content': 'This is the first time step, give an initial price prediction'}
#
#  Time: 0, agent: 3
#
# {'role': 'user', 'content': 'This is the first time step, give an initial price prediction'}
#
#  Time: 0, agent: 4
#
# {'role': 'user', 'content': 'This is the first time step, give an initial price prediction'}
#
#  Time: 0, agent: 5
#
# {'role': 'user', 'content': 'This is the first time step, give an initial price prediction'}
#
#  Time: 1, agent: 0
#
# {'role': 'user', 'content': '```Current time step: 2; market prices: 69.56;             your predictions: 50.0;             Total earnings: 0.0``` Make your next prediction'}
#
#  Time: 1, agent: 1
#
# {'role': 'user', 'content': '```Current time step: 2; market prices: 69.56;             your predictions: 50.0;             Total earnings: 0.0``` Make your next prediction'}
#
#  Time: 1, agent: 2
#
# {'role': 'user', 'content': '```Current time step: 2; market prices: 69.56;             your predictions: 50.0;             Total earnings: 0.0``` Make your next prediction'}
#
#  Time: 1, agent: 3
#
# {'role': 'user', 'content': '```Current time step: 2; market prices: 69.56;             your predictions: 50.0;             Total earnings: 0.0``` Make your next prediction'}
#
#  Time: 1, agent: 4
#
# {'role': 'user', 'content': '```Current time step: 2; market prices: 69.56;             your predictions: 50.0;             Total earnings: 0.0``` Make your next prediction'}
#
#  Time: 1, agent: 5
#
# {'role': 'user', 'content': '```Current time step: 2; market prices: 69.56;             your predictions: 50.0;             Total earnings: 0.0``` Make your next prediction'}
#
#  Time: 2, agent: 0
#
# {'role': 'user', 'content': '```Current time step: 3; market prices: 69.56, 52.57;             your predictions: 50.0, 72.0;             Total earnings: 0.0``` Make your next prediction'}
#
#  Time: 2, agent: 1
#
# {'role': 'user', 'content': '```Current time step: 3; market prices: 69.56, 52.57;             your predictions: 50.0, 62.0;             Total earnings: 0.0``` Make your next prediction'}
#
#  Time: 2, agent: 2
#
# {'role': 'user', 'content': '```Current time step: 3; market prices: 69.56, 52.57;             your predictions: 50.0, 70.0;             Total earnings: 0.0``` Make your next prediction'}
#
#  Time: 2, agent: 3
#
# {'role': 'user', 'content': '```Current time step: 3; market prices: 69.56, 52.57;             your predictions: 50.0, 62.0;             Total earnings: 0.0``` Make your next prediction'}
#
#  Time: 2, agent: 4
#
# {'role': 'user', 'content': '```Current time step: 3; market prices: 69.56, 52.57;             your predictions: 50.0, 72.0;             Total earnings: 0.0``` Make your next prediction'}
#
#  Time: 2, agent: 5
#
# {'role': 'user', 'content': '```Current time step: 3; market prices: 69.56, 52.57;             your predictions: 50.0, 70.0;             Total earnings: 0.0``` Make your next prediction'}
#
#  Time: 3, agent: 0
#
# {'role': 'user', 'content': '```Current time step: 4; market prices: 69.56, 52.57, 64.98;             your predictions: 50.0, 72.0, 55.0;             Total earnings: 0.0``` Make your next prediction'}
#
#  Time: 3, agent: 1
#
# {'role': 'user', 'content': '```Current time step: 4; market prices: 69.56, 52.57, 64.98;             your predictions: 50.0, 62.0, 54.0;             Total earnings: 0.0``` Make your next prediction'}
#
#  Time: 3, agent: 2
#
# {'role': 'user', 'content': '```Current time step: 4; market prices: 69.56, 52.57, 64.98;             your predictions: 50.0, 70.0, 55.0;             Total earnings: 0.0``` Make your next prediction'}
#
#  Time: 3, agent: 3
#
# {'role': 'user', 'content': '```Current time step: 4; market prices: 69.56, 52.57, 64.98;             your predictions: 50.0, 62.0, 55.0;             Total earnings: 0.0``` Make your next prediction'}
#
#  Time: 3, agent: 4
#
# {'role': 'user', 'content': '```Current time step: 4; market prices: 69.56, 52.57, 64.98;             your predictions: 50.0, 72.0, 55.0;             Total earnings: 0.0``` Make your next prediction'}
#
#  Time: 3, agent: 5
#
# {'role': 'user', 'content': '```Current time step: 4; market prices: 69.56, 52.57, 64.98;             your predictions: 50.0, 70.0, 55.0;             Total earnings: 0.0``` Make your next prediction'}
#
#  Time: 4, agent: 0
#
# {'role': 'user', 'content': '```Current time step: 5; market prices: 69.56, 52.57, 64.98, 55.84;             your predictions: 50.0, 72.0, 55.0, 67.0;             Total earnings: 0.0``` Make your next prediction'}
#
#  Time: 4, agent: 1
#
# {'role': 'user', 'content': '```Current time step: 5; market prices: 69.56, 52.57, 64.98, 55.84;             your predictions: 50.0, 62.0, 54.0, 60.0;             Total earnings: 0.32``` Make your next prediction'}
#
#  Time: 4, agent: 2
#
# {'role': 'user', 'content': '```Current time step: 5; market prices: 69.56, 52.57, 64.98, 55.84;             your predictions: 50.0, 70.0, 55.0, 60.0;             Total earnings: 0.32``` Make your next prediction'}
#
#  Time: 4, agent: 3
#
# {'role': 'user', 'content': '```Current time step: 5; market prices: 69.56, 52.57, 64.98, 55.84;             your predictions: 50.0, 62.0, 55.0, 68.0;             Total earnings: 0.0``` Make your next prediction'}
#
#  Time: 4, agent: 4
#
# {'role': 'user', 'content': '```Current time step: 5; market prices: 69.56, 52.57, 64.98, 55.84;             your predictions: 50.0, 72.0, 55.0, 66.0;             Total earnings: 0.0``` Make your next prediction'}
#
#  Time: 4, agent: 5
#
# {'role': 'user', 'content': '```Current time step: 5; market prices: 69.56, 52.57, 64.98, 55.84;             your predictions: 50.0, 70.0, 55.0, 66.0;             Total earnings: 0.0``` Make your next prediction'}
#
#  Time: 5, agent: 0
#
# {'role': 'user', 'content': '```Current time step: 6; market prices: 69.56, 52.57, 64.98, 55.84, 64.44;             your predictions: 50.0, 72.0, 55.0, 67.0, 54.5;             Total earnings: 0.0``` Make your next prediction'}
#
#  Time: 5, agent: 1
#
# {'role': 'user', 'content': '```Current time step: 6; market prices: 69.56, 52.57, 64.98, 55.84, 64.44;             your predictions: 50.0, 62.0, 54.0, 60.0, 58.0;             Total earnings: 0.4``` Make your next prediction'}
#
#  Time: 5, agent: 2
#
# {'role': 'user', 'content': '```Current time step: 6; market prices: 69.56, 52.57, 64.98, 55.84, 64.44;             your predictions: 50.0, 70.0, 55.0, 60.0, 57.0;             Total earnings: 0.32``` Make your next prediction'}
#
#  Time: 5, agent: 3
#
# {'role': 'user', 'content': '```Current time step: 6; market prices: 69.56, 52.57, 64.98, 55.84, 64.44;             your predictions: 50.0, 62.0, 55.0, 68.0, 57.5;             Total earnings: 0.01``` Make your next prediction'}
#
#  Time: 5, agent: 4
#
# {'role': 'user', 'content': '```Current time step: 6; market prices: 69.56, 52.57, 64.98, 55.84, 64.44;             your predictions: 50.0, 72.0, 55.0, 66.0, 57.5;             Total earnings: 0.01``` Make your next prediction'}
#
#  Time: 5, agent: 5
#
# {'role': 'user', 'content': '```Current time step: 6; market prices: 69.56, 52.57, 64.98, 55.84, 64.44;             your predictions: 50.0, 70.0, 55.0, 66.0, 54.0;             Total earnings: 0.0``` Make your next prediction'}
#
#  Time: 6, agent: 0
#
# {'role': 'user', 'content': '```Current time step: 7; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76;             your predictions: 50.0, 72.0, 55.0, 67.0, 54.5, 66.0;             Total earnings: 0.0``` Make your next prediction'}
#
#  Time: 6, agent: 1
#
# {'role': 'user', 'content': '```Current time step: 7; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76;             your predictions: 50.0, 62.0, 54.0, 60.0, 58.0, 66.0;             Total earnings: 0.4``` Make your next prediction'}
#
#  Time: 6, agent: 2
#
# {'role': 'user', 'content': '```Current time step: 7; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76;             your predictions: 50.0, 70.0, 55.0, 60.0, 57.0, 62.0;             Total earnings: 0.42000000000000004``` Make your next prediction'}
#
#  Time: 6, agent: 3
#
# {'role': 'user', 'content': '```Current time step: 7; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76;             your predictions: 50.0, 62.0, 55.0, 68.0, 57.5, 66.0;             Total earnings: 0.01``` Make your next prediction'}
#
#  Time: 6, agent: 4
#
# {'role': 'user', 'content': '```Current time step: 7; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76;             your predictions: 50.0, 72.0, 55.0, 66.0, 57.5, 66.0;             Total earnings: 0.01``` Make your next prediction'}
#
#  Time: 6, agent: 5
#
# {'role': 'user', 'content': '```Current time step: 7; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76;             your predictions: 50.0, 70.0, 55.0, 66.0, 54.0, 62.0;             Total earnings: 0.1``` Make your next prediction'}
#
#  Time: 7, agent: 0
#
# {'role': 'user', 'content': '```Current time step: 8; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64;             your predictions: 50.0, 72.0, 55.0, 67.0, 54.5, 66.0, 53.5;             Total earnings: 0.0``` Make your next prediction'}
#
#  Time: 7, agent: 1
#
# {'role': 'user', 'content': '```Current time step: 8; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64;             your predictions: 50.0, 62.0, 54.0, 60.0, 58.0, 66.0, 58.5;             Total earnings: 0.63``` Make your next prediction'}
#
#  Time: 7, agent: 2
#
# {'role': 'user', 'content': '```Current time step: 8; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64;             your predictions: 50.0, 70.0, 55.0, 60.0, 57.0, 62.0, 58.5;             Total earnings: 0.65``` Make your next prediction'}
#
#  Time: 7, agent: 3
#
# {'role': 'user', 'content': '```Current time step: 8; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64;             your predictions: 50.0, 62.0, 55.0, 68.0, 57.5, 66.0, 53.0;             Total earnings: 0.01``` Make your next prediction'}
#
#  Time: 7, agent: 4
#
# {'role': 'user', 'content': '```Current time step: 8; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64;             your predictions: 50.0, 72.0, 55.0, 66.0, 57.5, 66.0, 58.0;             Total earnings: 0.19``` Make your next prediction'}
#
#  Time: 7, agent: 5
#
# {'role': 'user', 'content': '```Current time step: 8; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64;             your predictions: 50.0, 70.0, 55.0, 66.0, 54.0, 62.0, 58.0;             Total earnings: 0.28``` Make your next prediction'}
#
#  Time: 8, agent: 0
#
# {'role': 'user', 'content': '```Current time step: 9; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41;             your predictions: 50.0, 72.0, 55.0, 67.0, 54.5, 66.0, 53.5, 65.0;             Total earnings: 0.0``` Make your next prediction'}
#
#  Time: 8, agent: 1
#
# {'role': 'user', 'content': '```Current time step: 9; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41;             your predictions: 50.0, 62.0, 54.0, 60.0, 58.0, 66.0, 58.5, 65.0;             Total earnings: 0.63``` Make your next prediction'}
#
#  Time: 8, agent: 2
#
# {'role': 'user', 'content': '```Current time step: 9; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41;             your predictions: 50.0, 70.0, 55.0, 60.0, 57.0, 62.0, 58.5, 65.0;             Total earnings: 0.65``` Make your next prediction'}
#
#  Time: 8, agent: 3
#
# {'role': 'user', 'content': '```Current time step: 9; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41;             your predictions: 50.0, 62.0, 55.0, 68.0, 57.5, 66.0, 53.0, 58.0;             Total earnings: 0.48``` Make your next prediction'}
#
#  Time: 8, agent: 4
#
# {'role': 'user', 'content': '```Current time step: 9; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41;             your predictions: 50.0, 72.0, 55.0, 66.0, 57.5, 66.0, 58.0, 65.0;             Total earnings: 0.19``` Make your next prediction'}
#
#  Time: 8, agent: 5
#
# {'role': 'user', 'content': '```Current time step: 9; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41;             your predictions: 50.0, 70.0, 55.0, 66.0, 54.0, 62.0, 58.0, 61.5;             Total earnings: 0.52``` Make your next prediction'}
#
#  Time: 9, agent: 0
#
# {'role': 'user', 'content': '```Current time step: 10; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19;             your predictions: 50.0, 72.0, 55.0, 67.0, 54.5, 66.0, 53.5, 65.0, 57.5;             Total earnings: 0.36``` Make your next prediction'}
#
#  Time: 9, agent: 1
#
# {'role': 'user', 'content': '```Current time step: 10; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19;             your predictions: 50.0, 62.0, 54.0, 60.0, 58.0, 66.0, 58.5, 65.0, 59.3;             Total earnings: 1.09``` Make your next prediction'}
#
#  Time: 9, agent: 2
#
# {'role': 'user', 'content': '```Current time step: 10; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19;             your predictions: 50.0, 70.0, 55.0, 60.0, 57.0, 62.0, 58.5, 65.0, 59.0;             Total earnings: 1.1``` Make your next prediction'}
#
#  Time: 9, agent: 3
#
# {'role': 'user', 'content': '```Current time step: 10; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19;             your predictions: 50.0, 62.0, 55.0, 68.0, 57.5, 66.0, 53.0, 58.0, 57.75;             Total earnings: 0.86``` Make your next prediction'}
#
#  Time: 9, agent: 4
#
# {'role': 'user', 'content': '```Current time step: 10; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19;             your predictions: 50.0, 72.0, 55.0, 66.0, 57.5, 66.0, 58.0, 65.0, 59.5;             Total earnings: 0.6599999999999999``` Make your next prediction'}
#
#  Time: 9, agent: 5
#
# {'role': 'user', 'content': '```Current time step: 10; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19;             your predictions: 50.0, 70.0, 55.0, 66.0, 54.0, 62.0, 58.0, 61.5, 60.0;             Total earnings: 1.01``` Make your next prediction'}
#
#  Time: 10, agent: 0
#
# {'role': 'user', 'content': '```Current time step: 11; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19, 58.31;             your predictions: 50.0, 72.0, 55.0, 67.0, 54.5, 66.0, 53.5, 65.0, 57.5, 62.0;             Total earnings: 0.72``` Make your next prediction'}
#
#  Time: 10, agent: 1
#
# {'role': 'user', 'content': '```Current time step: 11; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19, 58.31;             your predictions: 50.0, 62.0, 54.0, 60.0, 58.0, 66.0, 58.5, 65.0, 59.3, 62.1;             Total earnings: 1.44``` Make your next prediction'}
#
#  Time: 10, agent: 2
#
# {'role': 'user', 'content': '```Current time step: 11; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19, 58.31;             your predictions: 50.0, 70.0, 55.0, 60.0, 57.0, 62.0, 58.5, 65.0, 59.0, 62.5;             Total earnings: 1.4200000000000002``` Make your next prediction'}
#
#  Time: 10, agent: 3
#
# {'role': 'user', 'content': '```Current time step: 11; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19, 58.31;             your predictions: 50.0, 62.0, 55.0, 68.0, 57.5, 66.0, 53.0, 58.0, 57.75, 62.5;             Total earnings: 1.18``` Make your next prediction'}
#
#  Time: 10, agent: 4
#
# {'role': 'user', 'content': '```Current time step: 11; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19, 58.31;             your predictions: 50.0, 72.0, 55.0, 66.0, 57.5, 66.0, 58.0, 65.0, 59.5, 60.25;             Total earnings: 1.1199999999999999``` Make your next prediction'}
#
#  Time: 10, agent: 5
#
# {'role': 'user', 'content': '```Current time step: 11; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19, 58.31;             your predictions: 50.0, 70.0, 55.0, 66.0, 54.0, 62.0, 58.0, 61.5, 60.0, 62.5;             Total earnings: 1.33``` Make your next prediction'}
#
#  Time: 11, agent: 0
#
# {'role': 'user', 'content': '```Current time step: 12; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19, 58.31, 61.25;             your predictions: 50.0, 72.0, 55.0, 67.0, 54.5, 66.0, 53.5, 65.0, 57.5, 62.0, 59.0;             Total earnings: 1.17``` Make your next prediction'}
#
#  Time: 11, agent: 1
#
# {'role': 'user', 'content': '```Current time step: 12; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19, 58.31, 61.25;             your predictions: 50.0, 62.0, 54.0, 60.0, 58.0, 66.0, 58.5, 65.0, 59.3, 62.1, 59.5;             Total earnings: 1.91``` Make your next prediction'}
#
#  Time: 11, agent: 2
#
# {'role': 'user', 'content': '```Current time step: 12; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19, 58.31, 61.25;             your predictions: 50.0, 70.0, 55.0, 60.0, 57.0, 62.0, 58.5, 65.0, 59.0, 62.5, 56.5;             Total earnings: 1.6900000000000002``` Make your next prediction'}
#
#  Time: 11, agent: 3
#
# {'role': 'user', 'content': '```Current time step: 12; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19, 58.31, 61.25;             your predictions: 50.0, 62.0, 55.0, 68.0, 57.5, 66.0, 53.0, 58.0, 57.75, 62.5, 60.25;             Total earnings: 1.67``` Make your next prediction'}
#
#  Time: 11, agent: 4
#
# {'role': 'user', 'content': '```Current time step: 12; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19, 58.31, 61.25;             your predictions: 50.0, 72.0, 55.0, 66.0, 57.5, 66.0, 58.0, 65.0, 59.5, 60.25, 56.8;             Total earnings: 1.42``` Make your next prediction'}
#
#  Time: 11, agent: 5
#
# {'role': 'user', 'content': '```Current time step: 12; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19, 58.31, 61.25;             your predictions: 50.0, 70.0, 55.0, 66.0, 54.0, 62.0, 58.0, 61.5, 60.0, 62.5, 59.5;             Total earnings: 1.8``` Make your next prediction'}
#
#  Time: 12, agent: 0
#
# {'role': 'user', 'content': '```Current time step: 13; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19, 58.31, 61.25, 58.15;             your predictions: 50.0, 72.0, 55.0, 67.0, 54.5, 66.0, 53.5, 65.0, 57.5, 62.0, 59.0, 61.5;             Total earnings: 1.56``` Make your next prediction'}
#
#  Time: 12, agent: 1
#
# {'role': 'user', 'content': '```Current time step: 13; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19, 58.31, 61.25, 58.15;             your predictions: 50.0, 62.0, 54.0, 60.0, 58.0, 66.0, 58.5, 65.0, 59.3, 62.1, 59.5, 60.0;             Total earnings: 2.38``` Make your next prediction'}
#
#  Time: 12, agent: 2
#
# {'role': 'user', 'content': '```Current time step: 13; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19, 58.31, 61.25, 58.15;             your predictions: 50.0, 70.0, 55.0, 60.0, 57.0, 62.0, 58.5, 65.0, 59.0, 62.5, 56.5, 63.0;             Total earnings: 1.9500000000000002``` Make your next prediction'}
#
#  Time: 12, agent: 3
#
# {'role': 'user', 'content': '```Current time step: 13; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19, 58.31, 61.25, 58.15;             your predictions: 50.0, 62.0, 55.0, 68.0, 57.5, 66.0, 53.0, 58.0, 57.75, 62.5, 60.25, 61.75;             Total earnings: 2.04``` Make your next prediction'}
#
#  Time: 12, agent: 4
#
# {'role': 'user', 'content': '```Current time step: 13; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19, 58.31, 61.25, 58.15;             your predictions: 50.0, 72.0, 55.0, 66.0, 57.5, 66.0, 58.0, 65.0, 59.5, 60.25, 56.8, 62.0;             Total earnings: 1.77``` Make your next prediction'}
#
#  Time: 12, agent: 5
#
# {'role': 'user', 'content': '```Current time step: 13; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19, 58.31, 61.25, 58.15;             your predictions: 50.0, 70.0, 55.0, 66.0, 54.0, 62.0, 58.0, 61.5, 60.0, 62.5, 59.5, 62.0;             Total earnings: 2.15``` Make your next prediction'}
#
#  Time: 13, agent: 0
#
# {'role': 'user', 'content': '```Current time step: 14; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19, 58.31, 61.25, 58.15, 62.32;             your predictions: 50.0, 72.0, 55.0, 67.0, 54.5, 66.0, 53.5, 65.0, 57.5, 62.0, 59.0, 61.5, 57.0;             Total earnings: 1.77``` Make your next prediction'}
#
#  Time: 13, agent: 1
#
# {'role': 'user', 'content': '```Current time step: 14; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19, 58.31, 61.25, 58.15, 62.32;             your predictions: 50.0, 62.0, 54.0, 60.0, 58.0, 66.0, 58.5, 65.0, 59.3, 62.1, 59.5, 60.0, 57.5;             Total earnings: 2.6399999999999997``` Make your next prediction'}
#
#  Time: 13, agent: 2
#
# {'role': 'user', 'content': '```Current time step: 14; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19, 58.31, 61.25, 58.15, 62.32;             your predictions: 50.0, 70.0, 55.0, 60.0, 57.0, 62.0, 58.5, 65.0, 59.0, 62.5, 56.5, 63.0, 56.0;             Total earnings: 2.04``` Make your next prediction'}
#
#  Time: 13, agent: 3
#
# {'role': 'user', 'content': '```Current time step: 14; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19, 58.31, 61.25, 58.15, 62.32;             your predictions: 50.0, 62.0, 55.0, 68.0, 57.5, 66.0, 53.0, 58.0, 57.75, 62.5, 60.25, 61.75, 59.5;             Total earnings: 2.46``` Make your next prediction'}
#
#  Time: 13, agent: 4
#
# {'role': 'user', 'content': '```Current time step: 14; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19, 58.31, 61.25, 58.15, 62.32;             your predictions: 50.0, 72.0, 55.0, 66.0, 57.5, 66.0, 58.0, 65.0, 59.5, 60.25, 56.8, 62.0, 57.0;             Total earnings: 1.98``` Make your next prediction'}
#
#  Time: 13, agent: 5
#
# {'role': 'user', 'content': '```Current time step: 14; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19, 58.31, 61.25, 58.15, 62.32;             your predictions: 50.0, 70.0, 55.0, 66.0, 54.0, 62.0, 58.0, 61.5, 60.0, 62.5, 59.5, 62.0, 59.0;             Total earnings: 2.54``` Make your next prediction'}
#
#  Time: 14, agent: 0
#
# {'role': 'user', 'content': '```Current time step: 15; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19, 58.31, 61.25, 58.15, 62.32, 56.67;             your predictions: 50.0, 72.0, 55.0, 67.0, 54.5, 66.0, 53.5, 65.0, 57.5, 62.0, 59.0, 61.5, 57.0, 63.0;             Total earnings: 1.86``` Make your next prediction'}
#
#  Time: 14, agent: 1
#
# {'role': 'user', 'content': '```Current time step: 15; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19, 58.31, 61.25, 58.15, 62.32, 56.67;             your predictions: 50.0, 62.0, 54.0, 60.0, 58.0, 66.0, 58.5, 65.0, 59.3, 62.1, 59.5, 60.0, 57.5, 63.0;             Total earnings: 2.7299999999999995``` Make your next prediction'}
#
#  Time: 14, agent: 2
#
# {'role': 'user', 'content': '```Current time step: 15; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19, 58.31, 61.25, 58.15, 62.32, 56.67;             your predictions: 50.0, 70.0, 55.0, 60.0, 57.0, 62.0, 58.5, 65.0, 59.0, 62.5, 56.5, 63.0, 56.0, 65.5;             Total earnings: 2.04``` Make your next prediction'}
#
#  Time: 14, agent: 3
#
# {'role': 'user', 'content': '```Current time step: 15; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19, 58.31, 61.25, 58.15, 62.32, 56.67;             your predictions: 50.0, 62.0, 55.0, 68.0, 57.5, 66.0, 53.0, 58.0, 57.75, 62.5, 60.25, 61.75, 59.5, 63.0;             Total earnings: 2.55``` Make your next prediction'}
#
#  Time: 14, agent: 4
#
# {'role': 'user', 'content': '```Current time step: 15; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19, 58.31, 61.25, 58.15, 62.32, 56.67;             your predictions: 50.0, 72.0, 55.0, 66.0, 57.5, 66.0, 58.0, 65.0, 59.5, 60.25, 56.8, 62.0, 57.0, 63.0;             Total earnings: 2.07``` Make your next prediction'}
#
#  Time: 14, agent: 5
#
# {'role': 'user', 'content': '```Current time step: 15; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19, 58.31, 61.25, 58.15, 62.32, 56.67;             your predictions: 50.0, 70.0, 55.0, 66.0, 54.0, 62.0, 58.0, 61.5, 60.0, 62.5, 59.5, 62.0, 59.0, 63.0;             Total earnings: 2.63``` Make your next prediction'}
#
#  Time: 15, agent: 0
#
# {'role': 'user', 'content': '```Current time step: 16; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19, 58.31, 61.25, 58.15, 62.32, 56.67, 61.2;             your predictions: 50.0, 72.0, 55.0, 67.0, 54.5, 66.0, 53.5, 65.0, 57.5, 62.0, 59.0, 61.5, 57.0, 63.0, 58.0;             Total earnings: 2.2600000000000002``` Make your next prediction'}
#
#  Time: 15, agent: 1
#
# {'role': 'user', 'content': '```Current time step: 16; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19, 58.31, 61.25, 58.15, 62.32, 56.67, 61.2;             your predictions: 50.0, 62.0, 54.0, 60.0, 58.0, 66.0, 58.5, 65.0, 59.3, 62.1, 59.5, 60.0, 57.5, 63.0, 58.0;             Total earnings: 3.1299999999999994``` Make your next prediction'}
#
#  Time: 15, agent: 2
#
# {'role': 'user', 'content': '```Current time step: 16; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19, 58.31, 61.25, 58.15, 62.32, 56.67, 61.2;             your predictions: 50.0, 70.0, 55.0, 60.0, 57.0, 62.0, 58.5, 65.0, 59.0, 62.5, 56.5, 63.0, 56.0, 65.5, 59.0;             Total earnings: 2.49``` Make your next prediction'}
#
#  Time: 15, agent: 3
#
# {'role': 'user', 'content': '```Current time step: 16; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19, 58.31, 61.25, 58.15, 62.32, 56.67, 61.2;             your predictions: 50.0, 62.0, 55.0, 68.0, 57.5, 66.0, 53.0, 58.0, 57.75, 62.5, 60.25, 61.75, 59.5, 63.0, 60.5;             Total earnings: 3.05``` Make your next prediction'}
#
#  Time: 15, agent: 4
#
# {'role': 'user', 'content': '```Current time step: 16; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19, 58.31, 61.25, 58.15, 62.32, 56.67, 61.2;             your predictions: 50.0, 72.0, 55.0, 66.0, 57.5, 66.0, 58.0, 65.0, 59.5, 60.25, 56.8, 62.0, 57.0, 63.0, 58.0;             Total earnings: 2.4699999999999998``` Make your next prediction'}
#
#  Time: 15, agent: 5
#
# {'role': 'user', 'content': '```Current time step: 16; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19, 58.31, 61.25, 58.15, 62.32, 56.67, 61.2;             your predictions: 50.0, 70.0, 55.0, 66.0, 54.0, 62.0, 58.0, 61.5, 60.0, 62.5, 59.5, 62.0, 59.0, 63.0, 58.0;             Total earnings: 3.03``` Make your next prediction'}
#
#  Time: 16, agent: 0
#
# {'role': 'user', 'content': '```Current time step: 17; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19, 58.31, 61.25, 58.15, 62.32, 56.67, 61.2, 59.17;             your predictions: 50.0, 72.0, 55.0, 67.0, 54.5, 66.0, 53.5, 65.0, 57.5, 62.0, 59.0, 61.5, 57.0, 63.0, 58.0, 62.0;             Total earnings: 2.68``` Make your next prediction'}
#
#  Time: 16, agent: 1
#
# {'role': 'user', 'content': '```Current time step: 17; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19, 58.31, 61.25, 58.15, 62.32, 56.67, 61.2, 59.17;             your predictions: 50.0, 62.0, 54.0, 60.0, 58.0, 66.0, 58.5, 65.0, 59.3, 62.1, 59.5, 60.0, 57.5, 63.0, 58.0, 59.5;             Total earnings: 3.6300000000000003``` Make your next prediction'}
#
#  Time: 16, agent: 2
#
# {'role': 'user', 'content': '```Current time step: 17; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19, 58.31, 61.25, 58.15, 62.32, 56.67, 61.2, 59.17;             your predictions: 50.0, 70.0, 55.0, 60.0, 57.0, 62.0, 58.5, 65.0, 59.0, 62.5, 56.5, 63.0, 56.0, 65.5, 59.0, 62.3;             Total earnings: 2.89``` Make your next prediction'}
#
#  Time: 16, agent: 3
#
# {'role': 'user', 'content': '```Current time step: 17; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19, 58.31, 61.25, 58.15, 62.32, 56.67, 61.2, 59.17;             your predictions: 50.0, 62.0, 55.0, 68.0, 57.5, 66.0, 53.0, 58.0, 57.75, 62.5, 60.25, 61.75, 59.5, 63.0, 60.5, 61.0;             Total earnings: 3.52``` Make your next prediction'}
#
#  Time: 16, agent: 4
#
# {'role': 'user', 'content': '```Current time step: 17; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19, 58.31, 61.25, 58.15, 62.32, 56.67, 61.2, 59.17;             your predictions: 50.0, 72.0, 55.0, 66.0, 57.5, 66.0, 58.0, 65.0, 59.5, 60.25, 56.8, 62.0, 57.0, 63.0, 58.0, 61.75;             Total earnings: 2.9``` Make your next prediction'}
#
#  Time: 16, agent: 5
#
# {'role': 'user', 'content': '```Current time step: 17; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19, 58.31, 61.25, 58.15, 62.32, 56.67, 61.2, 59.17;             your predictions: 50.0, 70.0, 55.0, 66.0, 54.0, 62.0, 58.0, 61.5, 60.0, 62.5, 59.5, 62.0, 59.0, 63.0, 58.0, 60.5;             Total earnings: 3.51``` Make your next prediction'}
#
#  Time: 17, agent: 0
#
# {'role': 'user', 'content': '```Current time step: 18; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19, 58.31, 61.25, 58.15, 62.32, 56.67, 61.2, 59.17, 60.23;             your predictions: 50.0, 72.0, 55.0, 67.0, 54.5, 66.0, 53.5, 65.0, 57.5, 62.0, 59.0, 61.5, 57.0, 63.0, 58.0, 62.0, 60.0;             Total earnings: 3.18``` Make your next prediction'}
#
#  Time: 17, agent: 1
#
# {'role': 'user', 'content': '```Current time step: 18; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19, 58.31, 61.25, 58.15, 62.32, 56.67, 61.2, 59.17, 60.23;             your predictions: 50.0, 62.0, 54.0, 60.0, 58.0, 66.0, 58.5, 65.0, 59.3, 62.1, 59.5, 60.0, 57.5, 63.0, 58.0, 59.5, 60.5;             Total earnings: 4.130000000000001``` Make your next prediction'}
#
#  Time: 17, agent: 2
#
# {'role': 'user', 'content': '```Current time step: 18; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19, 58.31, 61.25, 58.15, 62.32, 56.67, 61.2, 59.17, 60.23;             your predictions: 50.0, 70.0, 55.0, 60.0, 57.0, 62.0, 58.5, 65.0, 59.0, 62.5, 56.5, 63.0, 56.0, 65.5, 59.0, 62.3, 58.9;             Total earnings: 3.37``` Make your next prediction'}
#
#  Time: 17, agent: 3
#
# {'role': 'user', 'content': '```Current time step: 18; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19, 58.31, 61.25, 58.15, 62.32, 56.67, 61.2, 59.17, 60.23;             your predictions: 50.0, 62.0, 55.0, 68.0, 57.5, 66.0, 53.0, 58.0, 57.75, 62.5, 60.25, 61.75, 59.5, 63.0, 60.5, 61.0, 60.75;             Total earnings: 4.02``` Make your next prediction'}
#
#  Time: 17, agent: 4
#
# {'role': 'user', 'content': '```Current time step: 18; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19, 58.31, 61.25, 58.15, 62.32, 56.67, 61.2, 59.17, 60.23;             your predictions: 50.0, 72.0, 55.0, 66.0, 57.5, 66.0, 58.0, 65.0, 59.5, 60.25, 56.8, 62.0, 57.0, 63.0, 58.0, 61.75, 60.5;             Total earnings: 3.4``` Make your next prediction'}
#
#  Time: 17, agent: 5
#
# {'role': 'user', 'content': '```Current time step: 18; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19, 58.31, 61.25, 58.15, 62.32, 56.67, 61.2, 59.17, 60.23;             your predictions: 50.0, 70.0, 55.0, 66.0, 54.0, 62.0, 58.0, 61.5, 60.0, 62.5, 59.5, 62.0, 59.0, 63.0, 58.0, 60.5, 60.0;             Total earnings: 4.01``` Make your next prediction'}
#
#  Time: 18, agent: 0
#
# {'role': 'user', 'content': '```Current time step: 19; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19, 58.31, 61.25, 58.15, 62.32, 56.67, 61.2, 59.17, 60.23, 59.52;             your predictions: 50.0, 72.0, 55.0, 67.0, 54.5, 66.0, 53.5, 65.0, 57.5, 62.0, 59.0, 61.5, 57.0, 63.0, 58.0, 62.0, 60.0, 60.5;             Total earnings: 3.67``` Make your next prediction'}
#
#  Time: 18, agent: 1
#
# {'role': 'user', 'content': '```Current time step: 19; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19, 58.31, 61.25, 58.15, 62.32, 56.67, 61.2, 59.17, 60.23, 59.52;             your predictions: 50.0, 62.0, 54.0, 60.0, 58.0, 66.0, 58.5, 65.0, 59.3, 62.1, 59.5, 60.0, 57.5, 63.0, 58.0, 59.5, 60.5, 59.2;             Total earnings: 4.630000000000001``` Make your next prediction'}
#
#  Time: 18, agent: 2
#
# {'role': 'user', 'content': '```Current time step: 19; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19, 58.31, 61.25, 58.15, 62.32, 56.67, 61.2, 59.17, 60.23, 59.52;             your predictions: 50.0, 70.0, 55.0, 60.0, 57.0, 62.0, 58.5, 65.0, 59.0, 62.5, 56.5, 63.0, 56.0, 65.5, 59.0, 62.3, 58.9, 61.5;             Total earnings: 3.83``` Make your next prediction'}
#
#  Time: 18, agent: 3
#
# {'role': 'user', 'content': '```Current time step: 19; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19, 58.31, 61.25, 58.15, 62.32, 56.67, 61.2, 59.17, 60.23, 59.52;             your predictions: 50.0, 62.0, 55.0, 68.0, 57.5, 66.0, 53.0, 58.0, 57.75, 62.5, 60.25, 61.75, 59.5, 63.0, 60.5, 61.0, 60.75, 61.5;             Total earnings: 4.4799999999999995``` Make your next prediction'}
#
#  Time: 18, agent: 4
#
# {'role': 'user', 'content': '```Current time step: 19; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19, 58.31, 61.25, 58.15, 62.32, 56.67, 61.2, 59.17, 60.23, 59.52;             your predictions: 50.0, 72.0, 55.0, 66.0, 57.5, 66.0, 58.0, 65.0, 59.5, 60.25, 56.8, 62.0, 57.0, 63.0, 58.0, 61.75, 60.5, 61.0;             Total earnings: 3.88``` Make your next prediction'}
#
#  Time: 18, agent: 5
#
# {'role': 'user', 'content': '```Current time step: 19; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19, 58.31, 61.25, 58.15, 62.32, 56.67, 61.2, 59.17, 60.23, 59.52;             your predictions: 50.0, 70.0, 55.0, 66.0, 54.0, 62.0, 58.0, 61.5, 60.0, 62.5, 59.5, 62.0, 59.0, 63.0, 58.0, 60.5, 60.0, 59.8;             Total earnings: 4.51``` Make your next prediction'}
#
#  Time: 19, agent: 0
#
# {'role': 'user', 'content': '```Current time step: 20; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19, 58.31, 61.25, 58.15, 62.32, 56.67, 61.2, 59.17, 60.23, 59.52, 59.47;             your predictions: 50.0, 72.0, 55.0, 67.0, 54.5, 66.0, 53.5, 65.0, 57.5, 62.0, 59.0, 61.5, 57.0, 63.0, 58.0, 62.0, 60.0, 60.5, 60.0;             Total earnings: 4.17``` Make your next prediction'}
#
#  Time: 19, agent: 1
#
# {'role': 'user', 'content': '```Current time step: 20; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19, 58.31, 61.25, 58.15, 62.32, 56.67, 61.2, 59.17, 60.23, 59.52, 59.47;             your predictions: 50.0, 62.0, 54.0, 60.0, 58.0, 66.0, 58.5, 65.0, 59.3, 62.1, 59.5, 60.0, 57.5, 63.0, 58.0, 59.5, 60.5, 59.2, 60.25;             Total earnings: 5.120000000000001``` Make your next prediction'}
#
#  Time: 19, agent: 2
#
# {'role': 'user', 'content': '```Current time step: 20; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19, 58.31, 61.25, 58.15, 62.32, 56.67, 61.2, 59.17, 60.23, 59.52, 59.47;             your predictions: 50.0, 70.0, 55.0, 60.0, 57.0, 62.0, 58.5, 65.0, 59.0, 62.5, 56.5, 63.0, 56.0, 65.5, 59.0, 62.3, 58.9, 61.5, 61.8;             Total earnings: 4.2700000000000005``` Make your next prediction'}
#
#  Time: 19, agent: 3
#
# {'role': 'user', 'content': '```Current time step: 20; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19, 58.31, 61.25, 58.15, 62.32, 56.67, 61.2, 59.17, 60.23, 59.52, 59.47;             your predictions: 50.0, 62.0, 55.0, 68.0, 57.5, 66.0, 53.0, 58.0, 57.75, 62.5, 60.25, 61.75, 59.5, 63.0, 60.5, 61.0, 60.75, 61.5, 60.5;             Total earnings: 4.97``` Make your next prediction'}
#
#  Time: 19, agent: 4
#
# {'role': 'user', 'content': '```Current time step: 20; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19, 58.31, 61.25, 58.15, 62.32, 56.67, 61.2, 59.17, 60.23, 59.52, 59.47;             your predictions: 50.0, 72.0, 55.0, 66.0, 57.5, 66.0, 58.0, 65.0, 59.5, 60.25, 56.8, 62.0, 57.0, 63.0, 58.0, 61.75, 60.5, 61.0, 60.0;             Total earnings: 4.38``` Make your next prediction'}
#
#  Time: 19, agent: 5
#
# {'role': 'user', 'content': '```Current time step: 20; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19, 58.31, 61.25, 58.15, 62.32, 56.67, 61.2, 59.17, 60.23, 59.52, 59.47;             your predictions: 50.0, 70.0, 55.0, 66.0, 54.0, 62.0, 58.0, 61.5, 60.0, 62.5, 59.5, 62.0, 59.0, 63.0, 58.0, 60.5, 60.0, 59.8, 60.1;             Total earnings: 5.01``` Make your next prediction'}
#
#  Time: 20, agent: 0
#
# {'role': 'user', 'content': '```Current time step: 21; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19, 58.31, 61.25, 58.15, 62.32, 56.67, 61.2, 59.17, 60.23, 59.52, 59.47, 60.36;             your predictions: 50.0, 72.0, 55.0, 67.0, 54.5, 66.0, 53.5, 65.0, 57.5, 62.0, 59.0, 61.5, 57.0, 63.0, 58.0, 62.0, 60.0, 60.5, 60.0, 58.95;             Total earnings: 4.65``` Make your next prediction'}
#
#  Time: 20, agent: 1
#
# {'role': 'user', 'content': '```Current time step: 21; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19, 58.31, 61.25, 58.15, 62.32, 56.67, 61.2, 59.17, 60.23, 59.52, 59.47, 60.36;             your predictions: 50.0, 62.0, 54.0, 60.0, 58.0, 66.0, 58.5, 65.0, 59.3, 62.1, 59.5, 60.0, 57.5, 63.0, 58.0, 59.5, 60.5, 59.2, 60.25, 60.75;             Total earnings: 5.620000000000001``` Make your next prediction'}
#
#  Time: 20, agent: 2
#
# {'role': 'user', 'content': '```Current time step: 21; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19, 58.31, 61.25, 58.15, 62.32, 56.67, 61.2, 59.17, 60.23, 59.52, 59.47, 60.36;             your predictions: 50.0, 70.0, 55.0, 60.0, 57.0, 62.0, 58.5, 65.0, 59.0, 62.5, 56.5, 63.0, 56.0, 65.5, 59.0, 62.3, 58.9, 61.5, 61.8, 59.2;             Total earnings: 4.760000000000001``` Make your next prediction'}
#
#  Time: 20, agent: 3
#
# {'role': 'user', 'content': '```Current time step: 21; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19, 58.31, 61.25, 58.15, 62.32, 56.67, 61.2, 59.17, 60.23, 59.52, 59.47, 60.36;             your predictions: 50.0, 62.0, 55.0, 68.0, 57.5, 66.0, 53.0, 58.0, 57.75, 62.5, 60.25, 61.75, 59.5, 63.0, 60.5, 61.0, 60.75, 61.5, 60.5, 60.75;             Total earnings: 5.47``` Make your next prediction'}
#
#  Time: 20, agent: 4
#
# {'role': 'user', 'content': '```Current time step: 21; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19, 58.31, 61.25, 58.15, 62.32, 56.67, 61.2, 59.17, 60.23, 59.52, 59.47, 60.36;             your predictions: 50.0, 72.0, 55.0, 66.0, 57.5, 66.0, 58.0, 65.0, 59.5, 60.25, 56.8, 62.0, 57.0, 63.0, 58.0, 61.75, 60.5, 61.0, 60.0, 59.4;             Total earnings: 4.87``` Make your next prediction'}
#
#  Time: 20, agent: 5
#
# {'role': 'user', 'content': '```Current time step: 21; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19, 58.31, 61.25, 58.15, 62.32, 56.67, 61.2, 59.17, 60.23, 59.52, 59.47, 60.36;             your predictions: 50.0, 70.0, 55.0, 66.0, 54.0, 62.0, 58.0, 61.5, 60.0, 62.5, 59.5, 62.0, 59.0, 63.0, 58.0, 60.5, 60.0, 59.8, 60.1, 59.5;             Total earnings: 5.5``` Make your next prediction'}
#
#  Time: 21, agent: 0
#
# {'role': 'user', 'content': '```Current time step: 22; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19, 58.31, 61.25, 58.15, 62.32, 56.67, 61.2, 59.17, 60.23, 59.52, 59.47, 60.36, 59.28;             your predictions: 50.0, 72.0, 55.0, 67.0, 54.5, 66.0, 53.5, 65.0, 57.5, 62.0, 59.0, 61.5, 57.0, 63.0, 58.0, 62.0, 60.0, 60.5, 60.0, 58.95, 61.0;             Total earnings: 5.12``` Make your next prediction'}
#
#  Time: 21, agent: 1
#
# {'role': 'user', 'content': '```Current time step: 22; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19, 58.31, 61.25, 58.15, 62.32, 56.67, 61.2, 59.17, 60.23, 59.52, 59.47, 60.36, 59.28;             your predictions: 50.0, 62.0, 54.0, 60.0, 58.0, 66.0, 58.5, 65.0, 59.3, 62.1, 59.5, 60.0, 57.5, 63.0, 58.0, 59.5, 60.5, 59.2, 60.25, 60.75, 60.85;             Total earnings: 6.090000000000001``` Make your next prediction'}
#
#  Time: 21, agent: 2
#
# {'role': 'user', 'content': '```Current time step: 22; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19, 58.31, 61.25, 58.15, 62.32, 56.67, 61.2, 59.17, 60.23, 59.52, 59.47, 60.36, 59.28;             your predictions: 50.0, 70.0, 55.0, 60.0, 57.0, 62.0, 58.5, 65.0, 59.0, 62.5, 56.5, 63.0, 56.0, 65.5, 59.0, 62.3, 58.9, 61.5, 61.8, 59.2, 61.5;             Total earnings: 5.210000000000001``` Make your next prediction'}
#
#  Time: 21, agent: 3
#
# {'role': 'user', 'content': '```Current time step: 22; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19, 58.31, 61.25, 58.15, 62.32, 56.67, 61.2, 59.17, 60.23, 59.52, 59.47, 60.36, 59.28;             your predictions: 50.0, 62.0, 55.0, 68.0, 57.5, 66.0, 53.0, 58.0, 57.75, 62.5, 60.25, 61.75, 59.5, 63.0, 60.5, 61.0, 60.75, 61.5, 60.5, 60.75, 61.0;             Total earnings: 5.9399999999999995``` Make your next prediction'}
#
#  Time: 21, agent: 4
#
# {'role': 'user', 'content': '```Current time step: 22; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19, 58.31, 61.25, 58.15, 62.32, 56.67, 61.2, 59.17, 60.23, 59.52, 59.47, 60.36, 59.28;             your predictions: 50.0, 72.0, 55.0, 66.0, 57.5, 66.0, 58.0, 65.0, 59.5, 60.25, 56.8, 62.0, 57.0, 63.0, 58.0, 61.75, 60.5, 61.0, 60.0, 59.4, 60.75;             Total earnings: 5.35``` Make your next prediction'}
#
#  Time: 21, agent: 5
#
# {'role': 'user', 'content': '```Current time step: 22; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19, 58.31, 61.25, 58.15, 62.32, 56.67, 61.2, 59.17, 60.23, 59.52, 59.47, 60.36, 59.28;             your predictions: 50.0, 70.0, 55.0, 66.0, 54.0, 62.0, 58.0, 61.5, 60.0, 62.5, 59.5, 62.0, 59.0, 63.0, 58.0, 60.5, 60.0, 59.8, 60.1, 59.5, 60.75;             Total earnings: 5.98``` Make your next prediction'}
#
#  Time: 22, agent: 0
#
# {'role': 'user', 'content': '```Current time step: 23; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19, 58.31, 61.25, 58.15, 62.32, 56.67, 61.2, 59.17, 60.23, 59.52, 59.47, 60.36, 59.28, 60.53;             your predictions: 50.0, 72.0, 55.0, 67.0, 54.5, 66.0, 53.5, 65.0, 57.5, 62.0, 59.0, 61.5, 57.0, 63.0, 58.0, 62.0, 60.0, 60.5, 60.0, 58.95, 61.0, 60.5;             Total earnings: 5.62``` Make your next prediction'}
#
#  Time: 22, agent: 1
#
# {'role': 'user', 'content': '```Current time step: 23; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19, 58.31, 61.25, 58.15, 62.32, 56.67, 61.2, 59.17, 60.23, 59.52, 59.47, 60.36, 59.28, 60.53;             your predictions: 50.0, 62.0, 54.0, 60.0, 58.0, 66.0, 58.5, 65.0, 59.3, 62.1, 59.5, 60.0, 57.5, 63.0, 58.0, 59.5, 60.5, 59.2, 60.25, 60.75, 60.85, 59.0;             Total earnings: 6.57``` Make your next prediction'}
#
#  Time: 22, agent: 2
#
# {'role': 'user', 'content': '```Current time step: 23; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19, 58.31, 61.25, 58.15, 62.32, 56.67, 61.2, 59.17, 60.23, 59.52, 59.47, 60.36, 59.28, 60.53;             your predictions: 50.0, 70.0, 55.0, 60.0, 57.0, 62.0, 58.5, 65.0, 59.0, 62.5, 56.5, 63.0, 56.0, 65.5, 59.0, 62.3, 58.9, 61.5, 61.8, 59.2, 61.5, 60.15;             Total earnings: 5.710000000000001``` Make your next prediction'}
#
#  Time: 22, agent: 3
#
# {'role': 'user', 'content': '```Current time step: 23; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19, 58.31, 61.25, 58.15, 62.32, 56.67, 61.2, 59.17, 60.23, 59.52, 59.47, 60.36, 59.28, 60.53;             your predictions: 50.0, 62.0, 55.0, 68.0, 57.5, 66.0, 53.0, 58.0, 57.75, 62.5, 60.25, 61.75, 59.5, 63.0, 60.5, 61.0, 60.75, 61.5, 60.5, 60.75, 61.0, 59.0;             Total earnings: 6.42``` Make your next prediction'}
#
#  Time: 22, agent: 4
#
# {'role': 'user', 'content': '```Current time step: 23; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19, 58.31, 61.25, 58.15, 62.32, 56.67, 61.2, 59.17, 60.23, 59.52, 59.47, 60.36, 59.28, 60.53;             your predictions: 50.0, 72.0, 55.0, 66.0, 57.5, 66.0, 58.0, 65.0, 59.5, 60.25, 56.8, 62.0, 57.0, 63.0, 58.0, 61.75, 60.5, 61.0, 60.0, 59.4, 60.75, 59.5;             Total earnings: 5.84``` Make your next prediction'}
#
#  Time: 22, agent: 5
#
# {'role': 'user', 'content': '```Current time step: 23; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19, 58.31, 61.25, 58.15, 62.32, 56.67, 61.2, 59.17, 60.23, 59.52, 59.47, 60.36, 59.28, 60.53;             your predictions: 50.0, 70.0, 55.0, 66.0, 54.0, 62.0, 58.0, 61.5, 60.0, 62.5, 59.5, 62.0, 59.0, 63.0, 58.0, 60.5, 60.0, 59.8, 60.1, 59.5, 60.75, 59.5;             Total earnings: 6.470000000000001``` Make your next prediction'}
#
#  Time: 23, agent: 0
#
# {'role': 'user', 'content': '```Current time step: 24; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19, 58.31, 61.25, 58.15, 62.32, 56.67, 61.2, 59.17, 60.23, 59.52, 59.47, 60.36, 59.28, 60.53, 58.95;             your predictions: 50.0, 72.0, 55.0, 67.0, 54.5, 66.0, 53.5, 65.0, 57.5, 62.0, 59.0, 61.5, 57.0, 63.0, 58.0, 62.0, 60.0, 60.5, 60.0, 58.95, 61.0, 60.5, 60.75;             Total earnings: 6.09``` Make your next prediction'}
#
#  Time: 23, agent: 1
#
# {'role': 'user', 'content': '```Current time step: 24; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19, 58.31, 61.25, 58.15, 62.32, 56.67, 61.2, 59.17, 60.23, 59.52, 59.47, 60.36, 59.28, 60.53, 58.95;             your predictions: 50.0, 62.0, 54.0, 60.0, 58.0, 66.0, 58.5, 65.0, 59.3, 62.1, 59.5, 60.0, 57.5, 63.0, 58.0, 59.5, 60.5, 59.2, 60.25, 60.75, 60.85, 59.0, 60.75;             Total earnings: 7.04``` Make your next prediction'}
#
#  Time: 23, agent: 2
#
# {'role': 'user', 'content': '```Current time step: 24; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19, 58.31, 61.25, 58.15, 62.32, 56.67, 61.2, 59.17, 60.23, 59.52, 59.47, 60.36, 59.28, 60.53, 58.95;             your predictions: 50.0, 70.0, 55.0, 60.0, 57.0, 62.0, 58.5, 65.0, 59.0, 62.5, 56.5, 63.0, 56.0, 65.5, 59.0, 62.3, 58.9, 61.5, 61.8, 59.2, 61.5, 60.15, 61.0;             Total earnings: 6.170000000000001``` Make your next prediction'}
#
#  Time: 23, agent: 3
#
# {'role': 'user', 'content': '```Current time step: 24; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19, 58.31, 61.25, 58.15, 62.32, 56.67, 61.2, 59.17, 60.23, 59.52, 59.47, 60.36, 59.28, 60.53, 58.95;             your predictions: 50.0, 62.0, 55.0, 68.0, 57.5, 66.0, 53.0, 58.0, 57.75, 62.5, 60.25, 61.75, 59.5, 63.0, 60.5, 61.0, 60.75, 61.5, 60.5, 60.75, 61.0, 59.0, 60.75;             Total earnings: 6.89``` Make your next prediction'}
#
#  Time: 23, agent: 4
#
# ...
#
#  Time: 46, agent: 5
#
# {'role': 'user', 'content': '```Current time step: 47; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19, 58.31, 61.25, 58.15, 62.32, 56.67, 61.2, 59.17, 60.23, 59.52, 59.47, 60.36, 59.28, 60.53, 58.95, 60.44, 59.72, 60.25, 59.76, 60.44, 59.29, 60.27, 59.61, 60.59, 59.55, 60.2, 60.0, 59.85, 59.78, 60.16, 59.77, 60.5, 59.75, 59.67, 60.29, 59.97, 59.67, 59.98;             your predictions: 50.0, 70.0, 55.0, 66.0, 54.0, 62.0, 58.0, 61.5, 60.0, 62.5, 59.5, 62.0, 59.0, 63.0, 58.0, 60.5, 60.0, 59.8, 60.1, 59.5, 60.75, 59.5, 60.25, 59.5, 59.95, 60.2, 60.5, 60.0, 60.4, 59.1, 59.8, 59.85, 60.65, 59.45, 60.3, 60.1, 59.7, 59.6, 60.2, 59.85, 60.55, 60.25, 59.9, 60.1, 60.05, 59.9;             Total earnings: 18.369999999999997``` Make your next prediction'}
#
#  Time: 47, agent: 0
#
# {'role': 'user', 'content': '```Current time step: 48; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19, 58.31, 61.25, 58.15, 62.32, 56.67, 61.2, 59.17, 60.23, 59.52, 59.47, 60.36, 59.28, 60.
# {'role': 'user', 'content': '```Current time step: 50; market prices: 69.56, 52.57, 64.98, 55.84, 64.44, 55.76, 63.64, 56.41, 61.19, 58.31, 61.25, 58.15, 62.32, 56.67, 61.2, 59.17, 60.23, 59.52, 59.47, 60.36, 59.28, 60.53, 58.95, 60.44, 59.72, 60.25, 59.76, 60.44, 59.29, 60.27, 59.61, 60.59, 59.55, 60.2, 60.0, 59.85, 59.78, 60.16, 59.77, 60.5, 59.75, 59.67, 60.29, 59.97, 59.67, 59.98, 59.47, 60.25, 59.75;             your predictions: 50.0, 70.0, 55.0, 66.0, 54.0, 62.0, 58.0, 61.5, 60.0, 62.5, 59.5, 62.0, 59.0, 63.0, 58.0, 60.5, 60.0, 59.8, 60.1, 59.5, 60.75, 59.5, 60.25, 59.5, 59.95, 60.2, 60.5, 60.0, 60.4, 59.1, 59.8, 59.85, 60.65, 59.45, 60.3, 60.1, 59.7, 59.6, 60.2, 59.85, 60.55, 60.25, 59.9, 60.1, 60.05, 59.9, 60.0, 59.7, 60.1;             Total earnings: 19.869999999999997``` Make your next prediction'}

# %%
memory = 3
temperature = 0.7
feedback = 'pos'
expmnt_num = 3

expmnt_num = check_existing_file(path_exp, expmnt_num, feedback, instruction_type, temperature, memory, n_steps, n_agents, gpt_model)
seed = expmnt_num
np.random.seed(seed)

p, pe, rewards, messages_list  = mod.run_experiment(seed,\
                expmnt_num, noise_mean, noise_sd, temperature, memory=memory, gpt_model=gpt_model, n_steps=n_steps, n_agents=n_agents,
                feedback=feedback, instruction_type=instruction_type, prints_on=False,\
                save_res_bool=True, path_exp=path_exp)
# Out:
# File expmnt_results_pos_original_30-50w_num_3_temp_0-7_memory_3_ntime_50_nagents_6_model_gpt-4-1106-preview.csv does not exist. Safe to proceed.

# %%
for i in range(3):

    memory = 3
    temperature = 0.7
    feedback = 'neg'
    expmnt_num = df["expmnt_num"].iloc[i]
    
    expmnt_num = check_existing_file(path_exp, expmnt_num, feedback, instruction_type, temperature, memory, n_steps, n_agents, gpt_model)
    seed = expmnt_num
    np.random.seed(seed)

    p, pe, rewards, messages_list  = mod.run_experiment(seed,\
                    expmnt_num, noise_mean, noise_sd, temperature, memory=memory, gpt_model=gpt_model, n_steps=n_steps, n_agents=n_agents,
                    feedback=feedback, instruction_type=instruction_type, prints_on=True,\
                    save_res_bool=True, path_exp=path_exp)

# %%
# for i in range(df.shape[0]):

#     memory = df["memory"].iloc[i]
#     temperature = df["temperature"].iloc[i]
#     feedback = df["feedback"].iloc[i]
#     expmnt_num = df["expmnt_num"].iloc[i]
    
#     expmnt_num = check_existing_file(path_exp, expmnt_num, feedback, instruction_type, temperature, memory, n_steps, n_agents, gpt_model)
#     seed = expmnt_num
#     np.random.seed(seed)

#     p, pe, rewards, messages_list  = mod.run_experiment(seed,\
#                     expmnt_num, noise_mean, noise_sd, temperature, memory=memory, gpt_model=gpt_model, n_steps=n_steps, n_agents=n_agents,
#                     feedback=feedback, instruction_type=instruction_type, prints_on=False,\
#                     save_res_bool=True, path_exp=path_exp)
# Out:
# File expmnt_results_pos_original_30-50w_num_1_temp_0-3_memory_1_ntime_50_nagents_6_model_gpt-4-0125-preview.csv does not exist. Safe to proceed.
# Error decoding JSON: Expecting value: line 1 column 1 (char 0)
# Error decoding JSON: Expecting value: line 1 column 1 (char 0)
# Error decoding JSON: Expecting value: line 1 column 1 (char 0)
# Error decoding JSON: Expecting value: line 1 column 1 (char 0)
# Error decoding JSON: Expecting value: line 1 column 1 (char 0)
# Error decoding JSON: Expecting value: line 1 column 1 (char 0)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 12
#       9 seed = expmnt_num
#      10 np.random.seed(seed)
# ---> 12 p, pe, rewards, messages_list  = mod.run_experiment(seed,\
#      13                 expmnt_num, noise_mean, noise_sd, temperature, memory=memory, gpt_model=gpt_model, n_steps=n_steps, n_agents=n_agents,
#      14                 feedback=feedback, instruction_type=instruction_type, prints_on=False,\
#      15                 save_res_bool=True, path_exp=path_exp)
#
# File ~/Library/CloudStorage/Dropbox/gpt_agents/gpt_agents/notebooks/../src/model.py:330, in run_experiment(seed, expmnt_num, noise_mean, noise_sd, temperature, memory, gpt_model, n_steps, n_agents, feedback, instruction_type, prints_on, save_res_bool, path_exp)
#     327 agent_messages = messages_list[i] # get agents context
#     329 # get agents's answer
# --> 330 pe, continue_simulation, agent_messages = get_agent_reply(agent_messages, new_message, temperature,\
#     331                                             continue_simulation, instructions_len, memory, gpt_model,\
#     332                                             new_message_json=new_message_json, prints_on=prints_on)
#     333 messages_list[i] = agent_messages # this line might be redundant but jic
#     335 if continue_simulation == False: break
#
# File ~/Library/CloudStorage/Dropbox/gpt_agents/gpt_agents/notebooks/../src/model.py:200, in get_agent_reply(agent_messages, new_message, temperature, continue_simulation, instructions_len, memory, gpt_model, new_message_json, prints_on)
#     195 attempt = 0 # attempts in getting a json format answer
#     197 while continue_simulation == True and got_reply == False and attempt <= 2:
#     199     reply_dict, got_reply, error, agent_messages \
# --> 200         = get_agent_reply_and_errors(agent_messages, new_message, temperature, \
#     201                                      instructions_len, memory, gpt_model, prints_on=prints_on)
#     203     if error == 'json':
#     204         attempt += 1
#
# File ~/Library/CloudStorage/Dropbox/gpt_agents/gpt_agents/notebooks/../src/model.py:150, in get_agent_reply_and_errors(agent_messages, new_message, temperature, instructions_len, memory, gpt_model, prints_on)
#     148     print(agent_messages[-1])
#     149 try:
# --> 150     chat_completion = client.chat.completions.create(
#     151         model=gpt_model,
#     152         messages=agent_remembered_messages,
#     153         temperature=temperature
#     154     )
#     155     reply = chat_completion.choices[0].message.content
#     156     if prints_on:
#
# File /opt/anaconda3/lib/python3.11/site-packages/openai/_utils/_utils.py:271, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     269             msg = f"Missing required argument: {quote(missing[0])}"
#     270     raise TypeError(msg)
# --> 271 return func(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.11/site-packages/openai/resources/chat/completions.py:648, in Completions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_tokens, n, presence_penalty, response_format, seed, stop, stream, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     599 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     600 def create(
#     601     self,
#    (...)
#     646     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     647 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
# --> 648     return self._post(
#     649         "/chat/completions",
#     650         body=maybe_transform(
#     651             {
#     652                 "messages": messages,
#     653                 "model": model,
#     654                 "frequency_penalty": frequency_penalty,
#     655                 "function_call": function_call,
#     656                 "functions": functions,
#     657                 "logit_bias": logit_bias,
#     658                 "logprobs": logprobs,
#     659                 "max_tokens": max_tokens,
#     660                 "n": n,
#     661                 "presence_penalty": presence_penalty,
#     662                 "response_format": response_format,
#     663                 "seed": seed,
#     664                 "stop": stop,
#     665                 "stream": stream,
#     666                 "temperature": temperature,
#     667                 "tool_choice": tool_choice,
#     668                 "tools": tools,
#     669                 "top_logprobs": top_logprobs,
#     670                 "top_p": top_p,
#     671                 "user": user,
#     672             },
#     673             completion_create_params.CompletionCreateParams,
#     674         ),
#     675         options=make_request_options(
#     676             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     677         ),
#     678         cast_to=ChatCompletion,
#     679         stream=stream or False,
#     680         stream_cls=Stream[ChatCompletionChunk],
#     681     )
#
# File /opt/anaconda3/lib/python3.11/site-packages/openai/_base_client.py:1179, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1165 def post(
#    1166     self,
#    1167     path: str,
#    (...)
#    1174     stream_cls: type[_StreamT] | None = None,
#    1175 ) -> ResponseT | _StreamT:
#    1176     opts = FinalRequestOptions.construct(
#    1177         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1178     )
# -> 1179     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File /opt/anaconda3/lib/python3.11/site-packages/openai/_base_client.py:868, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     859 def request(
#     860     self,
#     861     cast_to: Type[ResponseT],
#    (...)
#     866     stream_cls: type[_StreamT] | None = None,
#     867 ) -> ResponseT | _StreamT:
# --> 868     return self._request(
#     869         cast_to=cast_to,
#     870         options=options,
#     871         stream=stream,
#     872         stream_cls=stream_cls,
#     873         remaining_retries=remaining_retries,
#     874     )
#
# File /opt/anaconda3/lib/python3.11/site-packages/openai/_base_client.py:897, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     894     kwargs["auth"] = self.custom_auth
#     896 try:
# --> 897     response = self._client.send(
#     898         request,
#     899         stream=stream or self._should_stream_response_body(request=request),
#     900         **kwargs,
#     901     )
#     902 except httpx.TimeoutException as err:
#     903     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File /opt/anaconda3/lib/python3.11/site-packages/httpx/_client.py:915, in Client.send(self, request, stream, auth, follow_redirects)
#     907 follow_redirects = (
#     908     self.follow_redirects
#     909     if isinstance(follow_redirects, UseClientDefault)
#     910     else follow_redirects
#     911 )
#     913 auth = self._build_request_auth(request, auth)
# --> 915 response = self._send_handling_auth(
#     916     request,
#     917     auth=auth,
#     918     follow_redirects=follow_redirects,
#     919     history=[],
#     920 )
#     921 try:
#     922     if not stream:
#
# File /opt/anaconda3/lib/python3.11/site-packages/httpx/_client.py:943, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     940 request = next(auth_flow)
#     942 while True:
# --> 943     response = self._send_handling_redirects(
#     944         request,
#     945         follow_redirects=follow_redirects,
#     946         history=history,
#     947     )
#     948     try:
#     949         try:
#
# File /opt/anaconda3/lib/python3.11/site-packages/httpx/_client.py:980, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     977 for hook in self._event_hooks["request"]:
#     978     hook(request)
# --> 980 response = self._send_single_request(request)
#     981 try:
#     982     for hook in self._event_hooks["response"]:
#
# File /opt/anaconda3/lib/python3.11/site-packages/httpx/_client.py:1016, in Client._send_single_request(self, request)
#    1011     raise RuntimeError(
#    1012         "Attempted to send an async request with a sync Client instance."
#    1013     )
#    1015 with request_context(request=request):
# -> 1016     response = transport.handle_request(request)
#    1018 assert isinstance(response.stream, SyncByteStream)
#    1020 response.request = request
#
# File /opt/anaconda3/lib/python3.11/site-packages/httpx/_transports/default.py:231, in HTTPTransport.handle_request(self, request)
#     218 req = httpcore.Request(
#     219     method=request.method,
#     220     url=httpcore.URL(
#    (...)
#     228     extensions=request.extensions,
#     229 )
#     230 with map_httpcore_exceptions():
# --> 231     resp = self._pool.handle_request(req)
#     233 assert isinstance(resp.stream, typing.Iterable)
#     235 return Response(
#     236     status_code=resp.status,
#     237     headers=resp.headers,
#     238     stream=ResponseStream(resp.stream),
#     239     extensions=resp.extensions,
#     240 )
#
# File /opt/anaconda3/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:268, in ConnectionPool.handle_request(self, request)
#     266     with ShieldCancellation():
#     267         self.response_closed(status)
# --> 268     raise exc
#     269 else:
#     270     break
#
# File /opt/anaconda3/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:251, in ConnectionPool.handle_request(self, request)
#     248         raise exc
#     250 try:
# --> 251     response = connection.handle_request(request)
#     252 except ConnectionNotAvailable:
#     253     # The ConnectionNotAvailable exception is a special case, that
#     254     # indicates we need to retry the request on a new connection.
#    (...)
#     258     # might end up as an HTTP/2 connection, but which actually ends
#     259     # up as HTTP/1.1.
#     260     with self._pool_lock:
#     261         # Maintain our position in the request queue, but reset the
#     262         # status so that the request becomes queued again.
#
# File /opt/anaconda3/lib/python3.11/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     elif not self._connection.is_available():
#     101         raise ConnectionNotAvailable()
# --> 103 return self._connection.handle_request(request)
#
# File /opt/anaconda3/lib/python3.11/site-packages/httpcore/_sync/http11.py:133, in HTTP11Connection.handle_request(self, request)
#     131     with Trace("response_closed", logger, request) as trace:
#     132         self._response_closed()
# --> 133 raise exc
#
# File /opt/anaconda3/lib/python3.11/site-packages/httpcore/_sync/http11.py:111, in HTTP11Connection.handle_request(self, request)
#     101     pass
#     103 with Trace(
#     104     "receive_response_headers", logger, request, kwargs
#     105 ) as trace:
#     106     (
#     107         http_version,
#     108         status,
#     109         reason_phrase,
#     110         headers,
# --> 111     ) = self._receive_response_headers(**kwargs)
#     112     trace.return_value = (
#     113         http_version,
#     114         status,
#     115         reason_phrase,
#     116         headers,
#     117     )
#     119 return Response(
#     120     status=status,
#     121     headers=headers,
#    (...)
#     127     },
#     128 )
#
# File /opt/anaconda3/lib/python3.11/site-packages/httpcore/_sync/http11.py:176, in HTTP11Connection._receive_response_headers(self, request)
#     173 timeout = timeouts.get("read", None)
#     175 while True:
# --> 176     event = self._receive_event(timeout=timeout)
#     177     if isinstance(event, h11.Response):
#     178         break
#
# File /opt/anaconda3/lib/python3.11/site-packages/httpcore/_sync/http11.py:212, in HTTP11Connection._receive_event(self, timeout)
#     209     event = self._h11_state.next_event()
#     211 if event is h11.NEED_DATA:
# --> 212     data = self._network_stream.read(
#     213         self.READ_NUM_BYTES, timeout=timeout
#     214     )
#     216     # If we feed this case through h11 we'll raise an exception like:
#     217     #
#     218     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     222     # perspective. Instead we handle this case distinctly and treat
#     223     # it as a ConnectError.
#     224     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File /opt/anaconda3/lib/python3.11/site-packages/httpcore/_backends/sync.py:126, in SyncStream.read(self, max_bytes, timeout)
#     124 with map_exceptions(exc_map):
#     125     self._sock.settimeout(timeout)
# --> 126     return self._sock.recv(max_bytes)
#
# File /opt/anaconda3/lib/python3.11/ssl.py:1296, in SSLSocket.recv(self, buflen, flags)
#    1292     if flags != 0:
#    1293         raise ValueError(
#    1294             "non-zero flags not allowed in calls to recv() on %s" %
#    1295             self.__class__)
# -> 1296     return self.read(buflen)
#    1297 else:
#    1298     return super().recv(buflen, flags)
#
# File /opt/anaconda3/lib/python3.11/ssl.py:1169, in SSLSocket.read(self, len, buffer)
#    1167         return self._sslobj.read(len, buffer)
#    1168     else:
# -> 1169         return self._sslobj.read(len)
#    1170 except SSLError as x:
#    1171     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:
