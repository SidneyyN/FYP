# %%
import openai
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
import re
import time
from openai import OpenAI
import json
import pickle
import os

sys.path += ['../src/']

#from model import *
import model as mod
import model
from utils import *
from plotting_functions import *
from matplotlib.gridspec import GridSpec
from itertools import product

# %% [markdown]
# ## Other grid

# %%
# Define the lists
memory_values = [7, 10]
temperature_values = [1.0]
feedback_values = ['pos', 'neg']
expmnt_nums = [1, 2, 3]

# %%
gpt_model="gpt-4-1106-preview"
memory = memory_values[0]
temperature = temperature_values[0]
feedback_values = ['pos','neg']
expmnt_nums = [1, 2, 3]
plots_across_runs_and_feedback(feedback_values,expmnt_nums,gpt_model,memory,temperature)
# Out:
# /Users/maria/Library/CloudStorage/Dropbox/gpt_agents/gpt_agents/notebooks/../src/plotting_functions.py:116: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
gpt_model="gpt-4-1106-preview"
memory = memory_values[1]
temperature = temperature_values[0]
feedback_values = ['pos','neg']
expmnt_nums = [1, 2, 3]
plots_across_runs_and_feedback(feedback_values,expmnt_nums,gpt_model,memory,temperature)
# Out:
# /Users/maria/Library/CloudStorage/Dropbox/gpt_agents/gpt_agents/notebooks/../src/plotting_functions.py:116: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %% [markdown]
# ## Original grid below

# %%
# Define the lists
memory_values = [1, 3, 5]
temperature_values = [0.3, 0.7, 1.0]
feedback_values = ['pos', 'neg']
expmnt_nums = [1, 2, 3]

# %%
gpt_model="gpt-4-1106-preview"
memory = memory_values[0]
temperature = temperature_values[0]
feedback_values = ['pos','neg']
expmnt_nums = [1, 2, 3]
plots_across_runs_and_feedback(feedback_values,expmnt_nums,gpt_model,memory,temperature)
# Out:
# /Users/maria/Library/CloudStorage/Dropbox/gpt_agents/gpt_agents/notebooks/../src/plotting_functions.py:116: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
gpt_model="gpt-4-1106-preview"
memory = memory_values[0]
temperature = temperature_values[1]
feedback_values = ['pos','neg']
expmnt_nums = [1, 2, 3]
plots_across_runs_and_feedback(feedback_values,expmnt_nums,gpt_model,memory,temperature)
# Out:
# /Users/maria/Library/CloudStorage/Dropbox/gpt_agents/gpt_agents/notebooks/../src/plotting_functions.py:116: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
gpt_model="gpt-4-1106-preview"
memory = memory_values[0]
temperature = temperature_values[2]
feedback_values = ['pos','neg']
expmnt_nums = [1, 2, 3]
plots_across_runs_and_feedback(feedback_values,expmnt_nums,gpt_model,memory,temperature)
# Out:
# /Users/maria/Library/CloudStorage/Dropbox/gpt_agents/gpt_agents/notebooks/../src/plotting_functions.py:116: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
gpt_model="gpt-4-1106-preview"
memory = memory_values[1]
temperature = temperature_values[0]
feedback_values = ['pos','neg']
expmnt_nums = [1, 2, 3]
plots_across_runs_and_feedback(feedback_values,expmnt_nums,gpt_model,memory,temperature)
# Out:
# /Users/maria/Library/CloudStorage/Dropbox/gpt_agents/gpt_agents/notebooks/../src/plotting_functions.py:116: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
gpt_model="gpt-4-1106-preview"
memory = memory_values[1]
temperature = temperature_values[1]
feedback_values = ['pos','neg']
expmnt_nums = [1, 2, 3]
plots_across_runs_and_feedback(feedback_values,expmnt_nums,gpt_model,memory,temperature)
# Out:
# /Users/maria/Library/CloudStorage/Dropbox/gpt_agents/gpt_agents/notebooks/../src/plotting_functions.py:116: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
gpt_model="gpt-4-1106-preview"
memory = memory_values[1]
temperature = temperature_values[2]
feedback_values = ['pos','neg']
expmnt_nums = [1, 2, 3]
plots_across_runs_and_feedback(feedback_values,expmnt_nums,gpt_model,memory,temperature)
# Out:
# /Users/maria/Library/CloudStorage/Dropbox/gpt_agents/gpt_agents/notebooks/../src/plotting_functions.py:116: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
gpt_model="gpt-4-1106-preview"
memory = memory_values[2]
temperature = temperature_values[0]
feedback_values = ['pos','neg']
expmnt_nums = [1, 2, 3]
plots_across_runs_and_feedback(feedback_values,expmnt_nums,gpt_model,memory,temperature)
# Out:
# /Users/maria/Library/CloudStorage/Dropbox/gpt_agents/gpt_agents/notebooks/../src/plotting_functions.py:116: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
gpt_model="gpt-4-1106-preview"
memory = memory_values[2]
temperature = temperature_values[1]
feedback_values = ['pos','neg']
expmnt_nums = [1, 2, 3]
plots_across_runs_and_feedback(feedback_values,expmnt_nums,gpt_model,memory,temperature)
# Out:
# /Users/maria/Library/CloudStorage/Dropbox/gpt_agents/gpt_agents/notebooks/../src/plotting_functions.py:116: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
gpt_model="gpt-4-1106-preview"
memory = memory_values[2]
temperature = temperature_values[2]
feedback_values = ['pos','neg']
expmnt_nums = [1, 2, 3]
plots_across_runs_and_feedback(feedback_values,expmnt_nums,gpt_model,memory,1)
# Out:
# /Users/maria/Library/CloudStorage/Dropbox/gpt_agents/gpt_agents/notebooks/../src/plotting_functions.py:116: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %% [markdown]
# # GPT 3.5

# %%
gpt_model="gpt-3.5-turbo-1106"
memory = memory_values[0]
temperature = temperature_values[1]

plots_across_runs_and_feedback(feedback_values,expmnt_nums,gpt_model,memory,temperature)
# Out:
# /Users/maria/Library/CloudStorage/Dropbox/gpt_agents/gpt_agents/notebooks/../src/plotting_functions.py:116: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
gpt_model="gpt-3.5-turbo-1106"
memory = memory_values[0]
temperature = temperature_values[2]

plots_across_runs_and_feedback(feedback_values,expmnt_nums,gpt_model,memory,temperature)
# Out:
# /Users/maria/Library/CloudStorage/Dropbox/gpt_agents/gpt_agents/notebooks/../src/plotting_functions.py:116: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
gpt_model="gpt-3.5-turbo-1106"
memory = memory_values[1]
temperature = temperature_values[0]

plots_across_runs_and_feedback(feedback_values,expmnt_nums,gpt_model,memory,temperature)
# Out:
# /Users/maria/Library/CloudStorage/Dropbox/gpt_agents/gpt_agents/notebooks/../src/plotting_functions.py:116: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
gpt_model="gpt-3.5-turbo-1106"
memory = memory_values[1]
temperature = temperature_values[1]

plots_across_runs_and_feedback(feedback_values,expmnt_nums,gpt_model,memory,temperature)
# Out:
# /Users/maria/Library/CloudStorage/Dropbox/gpt_agents/gpt_agents/notebooks/../src/plotting_functions.py:116: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
gpt_model="gpt-3.5-turbo-1106"
memory = memory_values[1]
temperature = temperature_values[2]

plots_across_runs_and_feedback(feedback_values,expmnt_nums,gpt_model,memory,temperature)
# Out:
# /Users/maria/Library/CloudStorage/Dropbox/gpt_agents/gpt_agents/notebooks/../src/plotting_functions.py:116: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
gpt_model="gpt-3.5-turbo-1106"
memory = memory_values[2]
temperature = temperature_values[0]

plots_across_runs_and_feedback(feedback_values,expmnt_nums,gpt_model,memory,temperature)
# Out:
# /Users/maria/Library/CloudStorage/Dropbox/gpt_agents/gpt_agents/notebooks/../src/plotting_functions.py:116: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
gpt_model="gpt-3.5-turbo-1106"
memory = memory_values[2]
temperature = temperature_values[1]

plots_across_runs_and_feedback(feedback_values,expmnt_nums,gpt_model,memory,temperature)
# Out:
# /Users/maria/Library/CloudStorage/Dropbox/gpt_agents/gpt_agents/notebooks/../src/plotting_functions.py:116: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
gpt_model="gpt-3.5-turbo-1106"
memory = memory_values[2]
temperature = temperature_values[2]

plots_across_runs_and_feedback(feedback_values,expmnt_nums,gpt_model,memory,temperature)
# Out:
# /Users/maria/Library/CloudStorage/Dropbox/gpt_agents/gpt_agents/notebooks/../src/plotting_functions.py:116: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
