# %% [markdown]
# # Setup Before Running

# %%
import sys

# %%
sys.path += ["../src/"]
from utils import *

# %% [markdown]
# # Negative Feedback

# %% [markdown]
# ## Individual Personas

# %% [markdown]
# ### Momentum Trader

# %%
folder_path = "../results/experiments/experiment_batch_20250205_174207_Momentum_Trader"
output_file = "consolidated_results.csv"

consolidate_experiment_results(folder_path, output_file)
# Out:
# Reading file: c:\Users\Sidney\Documents\Year 3\Final Year Project\gpt_agents-master\results\experiments\experiment_batch_20250205_174207_Momentum_Trader\expmnt_results_neg_original_30-50w_num_10_temp_1_memory_3_ntime_50_nagents_5_model_gpt-3-5-turbo-0125.csv
# Columns in file: ['time_step', 'agent_id', 'predicted_price', 'actual_price', 'rewards', 'personality']
#
# Reading file: c:\Users\Sidney\Documents\Year 3\Final Year Project\gpt_agents-master\results\experiments\experiment_batch_20250205_174207_Momentum_Trader\expmnt_results_neg_original_30-50w_num_1_temp_1_memory_3_ntime_50_nagents_5_model_gpt-3-5-turbo-0125.csv
# Columns in file: ['time_step', 'agent_id', 'predicted_price', 'actual_price', 'rewards', 'personality']
#
# Reading file: c:\Users\Sidney\Documents\Year 3\Final Year Project\gpt_agents-master\results\experiments\experiment_batch_20250205_174207_Momentum_Trader\expmnt_results_neg_original_30-50w_num_2_temp_1_memory_3_ntime_50_nagents_5_model_gpt-3-5-turbo-0125.csv
# ...

# %% [markdown]
# ### Balanced Decision-Maker

# %%
folder_path = "../results/experiments/experiment_batch_20250205_010617_Balanced_Decision-Maker"
output_file = "consolidated_results.csv"

consolidate_experiment_results(folder_path, output_file)
# Out:
# Reading file: c:\Users\Sidney\Documents\Year 3\Final Year Project\gpt_agents-master\results\experiments\experiment_batch_20250205_010617_Balanced_Decision-Maker\consolidated_results.csv
# Columns in file: ['time_step', 'agent_id', 'mean_predicted_price', 'mean_actual_price']
# Skipping consolidated_results.csv: Missing required columns
#
# Reading file: c:\Users\Sidney\Documents\Year 3\Final Year Project\gpt_agents-master\results\experiments\experiment_batch_20250205_010617_Balanced_Decision-Maker\expmnt_results_neg_original_30-50w_num_10_temp_1_memory_3_ntime_50_nagents_5_model_gpt-3-5-turbo-0125.csv
# Columns in file: ['time_step', 'agent_id', 'predicted_price', 'actual_price', 'rewards', 'personality']
#
# Reading file: c:\Users\Sidney\Documents\Year 3\Final Year Project\gpt_agents-master\results\experiments\experiment_batch_20250205_010617_Balanced_Decision-Maker\expmnt_results_neg_original_30-50w_num_1_temp_1_memory_3_ntime_50_nagents_5_model_gpt-3-5-turbo-0125.csv
# ...

# %% [markdown]
# ### Market Analyst

# %%
folder_path = "../results/experiments/experiment_batch_20250205_014651_Market_Analyst"
output_file = "consolidated_results.csv"

consolidate_experiment_results(folder_path, output_file)
# Out:
# Reading file: c:\Users\Sidney\Documents\Year 3\Final Year Project\gpt_agents-master\results\experiments\experiment_batch_20250205_014651_Market_Analyst\expmnt_results_neg_original_30-50w_num_10_temp_1_memory_3_ntime_50_nagents_5_model_gpt-3-5-turbo-0125.csv
# Columns in file: ['time_step', 'agent_id', 'predicted_price', 'actual_price', 'rewards', 'personality']
#
# Reading file: c:\Users\Sidney\Documents\Year 3\Final Year Project\gpt_agents-master\results\experiments\experiment_batch_20250205_014651_Market_Analyst\expmnt_results_neg_original_30-50w_num_1_temp_1_memory_3_ntime_50_nagents_5_model_gpt-3-5-turbo-0125.csv
# Columns in file: ['time_step', 'agent_id', 'predicted_price', 'actual_price', 'rewards', 'personality']
#
# Reading file: c:\Users\Sidney\Documents\Year 3\Final Year Project\gpt_agents-master\results\experiments\experiment_batch_20250205_014651_Market_Analyst\expmnt_results_neg_original_30-50w_num_2_temp_1_memory_3_ntime_50_nagents_5_model_gpt-3-5-turbo-0125.csv
# ...

# %% [markdown]
# ### Contrarian Investor

# %%
folder_path = "../results/experiments/experiment_batch_20250205_022634_Contrarian_Investor"
output_file = "consolidated_results.csv"

consolidate_experiment_results(folder_path, output_file)
# Out:
# Reading file: c:\Users\Sidney\Documents\Year 3\Final Year Project\gpt_agents-master\results\experiments\experiment_batch_20250205_022634_Contrarian_Investor\expmnt_results_neg_original_30-50w_num_10_temp_1_memory_3_ntime_50_nagents_5_model_gpt-3-5-turbo-0125.csv
# Columns in file: ['time_step', 'agent_id', 'predicted_price', 'actual_price', 'rewards', 'personality']
#
# Reading file: c:\Users\Sidney\Documents\Year 3\Final Year Project\gpt_agents-master\results\experiments\experiment_batch_20250205_022634_Contrarian_Investor\expmnt_results_neg_original_30-50w_num_1_temp_1_memory_3_ntime_50_nagents_5_model_gpt-3-5-turbo-0125.csv
# Columns in file: ['time_step', 'agent_id', 'predicted_price', 'actual_price', 'rewards', 'personality']
#
# ...

# %% [markdown]
# ### Fundamentalist Trader

# %%
folder_path = "../results/experiments/experiment_batch_20250205_065144_Fundamentalist_Trader"
output_file = "consolidated_results.csv"

consolidate_experiment_results(folder_path, output_file)
# Out:
# Reading file: c:\Users\Sidney\Documents\Year 3\Final Year Project\gpt_agents-master\results\experiments\experiment_batch_20250205_065144_Fundamentalist_Trader\expmnt_results_neg_original_30-50w_num_10_temp_1_memory_3_ntime_50_nagents_5_model_gpt-3-5-turbo-0125.csv
# Columns in file: ['time_step', 'agent_id', 'predicted_price', 'actual_price', 'rewards', 'personality']
#
# Reading file: c:\Users\Sidney\Documents\Year 3\Final Year Project\gpt_agents-master\results\experiments\experiment_batch_20250205_065144_Fundamentalist_Trader\expmnt_results_neg_original_30-50w_num_1_temp_1_memory_3_ntime_50_nagents_5_model_gpt-3-5-turbo-0125.csv
# Columns in file: ['time_step', 'agent_id', 'predicted_price', 'actual_price', 'rewards', 'personality']
#
# ...

# %% [markdown]
# ## Mixed Experiments

# %% [markdown]
# ### High-Volatility Setup

# %%
folder_path = "../results/experiments/experiment_batch_20250308_201223_Neg_High-Volatility_Constraint"
output_file = "consolidated_results.csv"

consolidate_experiment_results(folder_path, output_file)
# Out:
# Reading file: c:\Users\Sidney\Documents\Year 3\Final Year Project\gpt_agents-master\results\experiments\experiment_batch_20250308_201223_Neg_High-Volatility_Constraint\expmnt_results_neg_original_30-50w_num_0_temp_1_memory_3_ntime_50_nagents_4_model_gpt-3-5-turbo-0125.csv
# Columns in file: ['time_step', 'agent_id', 'predicted_price', 'actual_price', 'rewards', 'personality']
#
# Reading file: c:\Users\Sidney\Documents\Year 3\Final Year Project\gpt_agents-master\results\experiments\experiment_batch_20250308_201223_Neg_High-Volatility_Constraint\expmnt_results_neg_original_30-50w_num_10_temp_1_memory_3_ntime_50_nagents_4_model_gpt-3-5-turbo-0125.csv
# Columns in file: ['time_step', 'agent_id', 'predicted_price', 'actual_price', 'rewards', 'personality']
#
# ...

# %% [markdown]
# ### High Volatility Setup (6 Agents)

# %%
folder_path = "../results/experiments/experiment_batch_20250427_004339_High-Volatility_Negative"
output_file = "consolidated_results.csv"

consolidate_experiment_results(folder_path, output_file)
# Out:
# Reading file: c:\Users\Sidney\Documents\Year_3\Final Year Project\gpt_agents-master\results\experiments\experiment_batch_20250427_004339_High-Volatility_Negative\expmnt_results_neg_original_30-50w_num_0_temp_1_memory_3_ntime_50_nagents_6_model_gpt-3-5-turbo-0125.csv
# Columns in file: ['time_step', 'agent_id', 'predicted_price', 'actual_price', 'rewards', 'personality']
#
# Reading file: c:\Users\Sidney\Documents\Year_3\Final Year Project\gpt_agents-master\results\experiments\experiment_batch_20250427_004339_High-Volatility_Negative\expmnt_results_neg_original_30-50w_num_10_temp_1_memory_3_ntime_50_nagents_6_model_gpt-3-5-turbo-0125.csv
# Columns in file: ['time_step', 'agent_id', 'predicted_price', 'actual_price', 'rewards', 'personality']
#
# ...

# %% [markdown]
# ### Stability-Focused Setup

# %%
folder_path = "../results/experiments/experiment_batch_20250308_205627_Stability-Focused_Negative"
output_file = "consolidated_results.csv"

consolidate_experiment_results(folder_path, output_file)
# Out:
# Reading file: c:\Users\Sidney\Documents\Year 3\Final Year Project\gpt_agents-master\results\experiments\experiment_batch_20250308_205627_Stability-Focused_Negative\expmnt_results_neg_original_30-50w_num_0_temp_1_memory_3_ntime_50_nagents_4_model_gpt-3-5-turbo-0125.csv
# Columns in file: ['time_step', 'agent_id', 'predicted_price', 'actual_price', 'rewards', 'personality']
#
# Reading file: c:\Users\Sidney\Documents\Year 3\Final Year Project\gpt_agents-master\results\experiments\experiment_batch_20250308_205627_Stability-Focused_Negative\expmnt_results_neg_original_30-50w_num_10_temp_1_memory_3_ntime_50_nagents_4_model_gpt-3-5-turbo-0125.csv
# Columns in file: ['time_step', 'agent_id', 'predicted_price', 'actual_price', 'rewards', 'personality']
#
# ...

# %% [markdown]
# ### Stability-Focused Setup (6 agents)

# %%
folder_path = "../results/experiments/experiment_batch_20250427_013541_Stability-Focused_Negative"
output_file = "consolidated_results.csv"

consolidate_experiment_results(folder_path, output_file)
# Out:
# Reading file: c:\Users\Sidney\Documents\Year_3\Final Year Project\gpt_agents-master\results\experiments\experiment_batch_20250427_013541_Stability-Focused_Negative\expmnt_results_neg_original_30-50w_num_10_temp_1_memory_3_ntime_50_nagents_6_model_gpt-3-5-turbo-0125.csv
# Columns in file: ['time_step', 'agent_id', 'predicted_price', 'actual_price', 'rewards', 'personality']
#
# Reading file: c:\Users\Sidney\Documents\Year_3\Final Year Project\gpt_agents-master\results\experiments\experiment_batch_20250427_013541_Stability-Focused_Negative\expmnt_results_neg_original_30-50w_num_1_temp_1_memory_3_ntime_50_nagents_6_model_gpt-3-5-turbo-0125.csv
# Columns in file: ['time_step', 'agent_id', 'predicted_price', 'actual_price', 'rewards', 'personality']
#
# ...

# %% [markdown]
# ### Realistic, Diverse Setup

# %%
folder_path = "../results/experiments/experiment_batch_20250308_213719_Neg_Realistic_Constraint"
output_file = "consolidated_results.csv"

consolidate_experiment_results(folder_path, output_file)
# Out:
# Reading file: c:\Users\Sidney\Documents\Year 3\Final Year Project\gpt_agents-master\results\experiments\experiment_batch_20250308_213719_Neg_Realistic_Constraint\expmnt_results_neg_original_30-50w_num_0_temp_1_memory_3_ntime_50_nagents_6_model_gpt-3-5-turbo-0125.csv
# Columns in file: ['time_step', 'agent_id', 'predicted_price', 'actual_price', 'rewards', 'personality']
#
# Reading file: c:\Users\Sidney\Documents\Year 3\Final Year Project\gpt_agents-master\results\experiments\experiment_batch_20250308_213719_Neg_Realistic_Constraint\expmnt_results_neg_original_30-50w_num_10_temp_1_memory_3_ntime_50_nagents_6_model_gpt-3-5-turbo-0125.csv
# Columns in file: ['time_step', 'agent_id', 'predicted_price', 'actual_price', 'rewards', 'personality']
#
# ...

# %% [markdown]
# # Positive Feedback

# %% [markdown]
# ## Individual Personas

# %% [markdown]
# ### Aggressive Speculator (WITH CONSTRAINTS)

# %%
folder_path = "../results/experiments/experiment_batch_20250316_175510_Pos_Aggr_Speculator_Constraint"
output_file = "consolidated_results.csv"

consolidate_experiment_results(folder_path, output_file)
# Out:
# Reading file: c:\Users\Sidney\Documents\Year 3\Final Year Project\gpt_agents-master\results\experiments\experiment_batch_20250316_175510_Pos_Aggr_Speculator_Constraint\expmnt_results_pos_original_30-50w_num_0_temp_1_memory_3_ntime_50_nagents_5_model_gpt-3-5-turbo-0125.csv
# Columns in file: ['time_step', 'agent_id', 'predicted_price', 'actual_price', 'rewards', 'personality']
#
# Reading file: c:\Users\Sidney\Documents\Year 3\Final Year Project\gpt_agents-master\results\experiments\experiment_batch_20250316_175510_Pos_Aggr_Speculator_Constraint\expmnt_results_pos_original_30-50w_num_10_temp_1_memory_3_ntime_50_nagents_5_model_gpt-3-5-turbo-0125.csv
# Columns in file: ['time_step', 'agent_id', 'predicted_price', 'actual_price', 'rewards', 'personality']
#
# ...

# %% [markdown]
# ## Mixed Setups

# %% [markdown]
# ### High-Volatility Setup (No Constraint)

# %%
folder_path = "../results/experiments/experiment_batch_20250226_121541_High-volatility"
output_file = "consolidated_results.csv"

consolidate_experiment_results(folder_path, output_file)
# Out:
# Reading file: c:\Users\Sidney\Documents\Year 3\Final Year Project\gpt_agents-master\results\experiments\experiment_batch_20250226_121541_High-volatility\expmnt_results_pos_original_30-50w_num_0_temp_1_memory_3_ntime_50_nagents_4_model_gpt-3-5-turbo-0125.csv
# Columns in file: ['time_step', 'agent_id', 'predicted_price', 'actual_price', 'rewards', 'personality']
#
# Reading file: c:\Users\Sidney\Documents\Year 3\Final Year Project\gpt_agents-master\results\experiments\experiment_batch_20250226_121541_High-volatility\expmnt_results_pos_original_30-50w_num_10_temp_1_memory_3_ntime_50_nagents_4_model_gpt-3-5-turbo-0125.csv
# Columns in file: ['time_step', 'agent_id', 'predicted_price', 'actual_price', 'rewards', 'personality']
#
# Reading file: c:\Users\Sidney\Documents\Year 3\Final Year Project\gpt_agents-master\results\experiments\experiment_batch_20250226_121541_High-volatility\expmnt_results_pos_original_30-50w_num_1_temp_1_memory_3_ntime_50_nagents_4_model_gpt-3-5-turbo-0125.csv
# ...

# %% [markdown]
# ### High-Volatility Setup (With Constraint)

# %%
folder_path = "../results/experiments/experiment_batch_20250308_153210_Pos_High-Vol_Constraint"
output_file = "consolidated_results.csv"

consolidate_experiment_results(folder_path, output_file)
# Out:
# Reading file: c:\Users\Sidney\Documents\Year 3\Final Year Project\gpt_agents-master\results\experiments\experiment_batch_20250308_153210_Pos_High-Vol_Constraint\expmnt_results_pos_original_30-50w_num_0_temp_1_memory_3_ntime_50_nagents_4_model_gpt-3-5-turbo-0125.csv
# Columns in file: ['time_step', 'agent_id', 'predicted_price', 'actual_price', 'rewards', 'personality']
#
# Reading file: c:\Users\Sidney\Documents\Year 3\Final Year Project\gpt_agents-master\results\experiments\experiment_batch_20250308_153210_Pos_High-Vol_Constraint\expmnt_results_pos_original_30-50w_num_10_temp_1_memory_3_ntime_50_nagents_4_model_gpt-3-5-turbo-0125.csv
# Columns in file: ['time_step', 'agent_id', 'predicted_price', 'actual_price', 'rewards', 'personality']
#
# ...

# %% [markdown]
# ### High-Volatility Setup without constraints (6 Agents)

# %%
folder_path = "../results/experiments/experiment_batch_20250427_123547_High-volatility"
output_file = "consolidated_results.csv"

consolidate_experiment_results(folder_path, output_file)
# Out:
# Reading file: c:\Users\Sidney\Documents\Year_3\Final Year Project\gpt_agents-master\results\experiments\experiment_batch_20250427_123547_High-volatility\expmnt_results_pos_original_30-50w_num_0_temp_1_memory_3_ntime_50_nagents_6_model_gpt-3-5-turbo-0125.csv
# Columns in file: ['time_step', 'agent_id', 'predicted_price', 'actual_price', 'rewards', 'personality']
#
# Reading file: c:\Users\Sidney\Documents\Year_3\Final Year Project\gpt_agents-master\results\experiments\experiment_batch_20250427_123547_High-volatility\expmnt_results_pos_original_30-50w_num_10_temp_1_memory_3_ntime_50_nagents_6_model_gpt-3-5-turbo-0125.csv
# Columns in file: ['time_step', 'agent_id', 'predicted_price', 'actual_price', 'rewards', 'personality']
#
# Reading file: c:\Users\Sidney\Documents\Year_3\Final Year Project\gpt_agents-master\results\experiments\experiment_batch_20250427_123547_High-volatility\expmnt_results_pos_original_30-50w_num_1_temp_1_memory_3_ntime_50_nagents_6_model_gpt-3-5-turbo-0125.csv
# ...

# %% [markdown]
# ### Stability-Focused Setup

# %%
folder_path = "../results/experiments/experiment_batch_20250226_130928_Stability-Focused"
output_file = "consolidated_results.csv"

consolidate_experiment_results(folder_path, output_file)
# Out:
# Reading file: c:\Users\Sidney\Documents\Year 3\Final Year Project\gpt_agents-master\results\experiments\experiment_batch_20250226_130928_Stability-Focused\expmnt_results_pos_original_30-50w_num_0_temp_1_memory_3_ntime_50_nagents_4_model_gpt-3-5-turbo-0125.csv
# Columns in file: ['time_step', 'agent_id', 'predicted_price', 'actual_price', 'rewards', 'personality']
#
# Reading file: c:\Users\Sidney\Documents\Year 3\Final Year Project\gpt_agents-master\results\experiments\experiment_batch_20250226_130928_Stability-Focused\expmnt_results_pos_original_30-50w_num_10_temp_1_memory_3_ntime_50_nagents_4_model_gpt-3-5-turbo-0125.csv
# Columns in file: ['time_step', 'agent_id', 'predicted_price', 'actual_price', 'rewards', 'personality']
#
# ...

# %% [markdown]
# ### Stability-Focused Setup (6 agents)

# %%
folder_path = "../results/experiments/experiment_batch_20250427_134105_Stability-Focused"
output_file = "consolidated_results.csv"

consolidate_experiment_results(folder_path, output_file)
# Out:
# Reading file: c:\Users\Sidney\Documents\Year_3\Final Year Project\gpt_agents-master\results\experiments\experiment_batch_20250427_134105_Stability-Focused\expmnt_results_pos_original_30-50w_num_10_temp_1_memory_3_ntime_50_nagents_6_model_gpt-3-5-turbo-0125.csv
# Columns in file: ['time_step', 'agent_id', 'predicted_price', 'actual_price', 'rewards', 'personality']
#
# Reading file: c:\Users\Sidney\Documents\Year_3\Final Year Project\gpt_agents-master\results\experiments\experiment_batch_20250427_134105_Stability-Focused\expmnt_results_pos_original_30-50w_num_1_temp_1_memory_3_ntime_50_nagents_6_model_gpt-3-5-turbo-0125.csv
# Columns in file: ['time_step', 'agent_id', 'predicted_price', 'actual_price', 'rewards', 'personality']
#
# ...

# %% [markdown]
# ### Realistic, Diverse Market Scenario (NO CONSTRAINT)

# %%
folder_path = "../results/experiments/experiment_batch_20250226_143324_Realistic"
output_file = "consolidated_results.csv"

consolidate_experiment_results(folder_path, output_file)
# Out:
# Reading file: c:\Users\Sidney\Documents\Year 3\Final Year Project\gpt_agents-master\results\experiments\experiment_batch_20250226_143324_Realistic\expmnt_results_pos_original_30-50w_num_0_temp_1_memory_3_ntime_50_nagents_6_model_gpt-3-5-turbo-0125.csv
# Columns in file: ['time_step', 'agent_id', 'predicted_price', 'actual_price', 'rewards', 'personality']
#
# Reading file: c:\Users\Sidney\Documents\Year 3\Final Year Project\gpt_agents-master\results\experiments\experiment_batch_20250226_143324_Realistic\expmnt_results_pos_original_30-50w_num_10_temp_1_memory_3_ntime_50_nagents_6_model_gpt-3-5-turbo-0125.csv
# Columns in file: ['time_step', 'agent_id', 'predicted_price', 'actual_price', 'rewards', 'personality']
#
# Reading file: c:\Users\Sidney\Documents\Year 3\Final Year Project\gpt_agents-master\results\experiments\experiment_batch_20250226_143324_Realistic\expmnt_results_pos_original_30-50w_num_1_temp_1_memory_3_ntime_50_nagents_6_model_gpt-3-5-turbo-0125.csv
# ...

# %% [markdown]
# ### Realistic, Diverse Market Scenario (WITH CONSTRAINT)

# %%
folder_path = "../results/experiments/experiment_batch_20250308_161229_Pos_Realistic_Constraint"
output_file = "consolidated_results.csv"

consolidate_experiment_results(folder_path, output_file)
# Out:
# Reading file: c:\Users\Sidney\Documents\Year 3\Final Year Project\gpt_agents-master\results\experiments\experiment_batch_20250308_161229_Pos_Realistic_Constraint\expmnt_results_pos_original_30-50w_num_10_temp_1_memory_3_ntime_50_nagents_6_model_gpt-3-5-turbo-0125.csv
# Columns in file: ['time_step', 'agent_id', 'predicted_price', 'actual_price', 'rewards', 'personality']
#
# Reading file: c:\Users\Sidney\Documents\Year 3\Final Year Project\gpt_agents-master\results\experiments\experiment_batch_20250308_161229_Pos_Realistic_Constraint\expmnt_results_pos_original_30-50w_num_1_temp_1_memory_3_ntime_50_nagents_6_model_gpt-3-5-turbo-0125.csv
# Columns in file: ['time_step', 'agent_id', 'predicted_price', 'actual_price', 'rewards', 'personality']
#
# ...
